# %% [markdown]
# # Burning Food Postlab <font color='blue'>Version 1.0</font>

# %%
import numpy as np
from datascience import *

# %% [markdown]
# Welcome to the Burning Food Postlab! You should have gotten several values for each type of chip tested. Consult your table, and replace the `...`'s in the following cell accordingly. We will work one chip type at a time.

# %% [markdown]
# ## Chip 1

# %%
name_1 = ...

total_mass_1 = ...

serving_size_1 = ...

Cal_per_serving_1 = ...

initial_mass_1 = ...

final_mass_1 = ...

starting_temp_1 = ...

peak_temp_1 = ...

# %% [markdown]
# ### Step 1
# First, we need to see how much of the chip burned.
#
# $$mass\;burned = final\;chip\;mass - initial\;chip\;mass$$

# %%
mass_burned_1 = ...
mass_burned_1

# %% [markdown]
# ### Step 2
# Second, let's get the amount of heat that was given off by the burning of the chip. We'll use this handy formula:
#
# $$q = mc\Delta T$$
#
# where
# * $q$ is the heat in 'small' calories (cal)
# * $m$ is the mass of the water (100 grams here)
# * $c$ is the specific heat of water (1 cal/$\degree$C)
# * $\Delta T$ is the change in temperature (from the initial to the peak)
#
# Use your nifty coding skills to get $q$.

# %%
m = ...

c = ...

delta_T_1 = ... # delta is that triangle symbol

# calculate q here!
q_1 = ...
q_1

# %% [markdown]
# ### Step 3
# You may have noticed that I specified that $q$ is in 'small' calories, and that is because the 'big' Calorie unit (Cal) you see on food packaging is actually **different** from the 'small' calorie unit typically used in chemistry and physics (cal).
#
# Specifically, one 'big' Calorie is equal to 1000 'small' calories.
#
# $$ big\;Calories = \frac{small\;calories}{1000}$$
#
# Convert your `q_1` amount from earlier to big Calories.

# %%
q_Cal_1 = ...
q_Cal_1

# %% [markdown]
# ### Step 4
# Let's look at what we have computed so far. We know that we burned some mass of chip (Step 1) and that released some amount of energy (Step 3). This means that that amount of energy was originally stored within that mass of chip.
#
# Compute how much energy is stored in one gram of chip.
#
# $$Calories\;per\;gram = \frac{Calories}{Burned\;Mass}$$

# %%
Cal_per_gram_1 = ...
Cal_per_gram_1

# %% [markdown]
# ### Step 5
# Finally, remember that Calories on the packaging are listed in terms of serving size. Multiply `Cal_per_gram_1` by the listed serving size (which should be stored in `serving_size_1`).

# %%
exp_Cal_per_serving_1 = ...
exp_Cal_per_serving_1

# %% [markdown]
# ### Step 6
# The `exp` in `exp_Cal_per_serving_1` represents the amount you obtained experimentally; the actual listed Calories per serving size is stored in `Cal_per_serving_1`.
#
# Use this percent error equation to measure how different your experimental value was from the actual.
#
# $$percent\;error = \lvert \frac{actual-experimental}{actual}\rvert * 100$$
#
# (The vertical bars represent absolute value. You can get that through the `abs()` function.)

# %%
pct_error_1 = ...
pct_error_1

# %% [markdown]
# How different was your value from the listed value? Typically, percent errors of 5% or less are acceptable for labs like these. What factors could have caused your error to occur?

# %% [markdown]
# **<Replace this with your answer!>**

# %% [markdown]
# ## Chip 2
# For Chips beyond the first, we will give you just the variables you need to fill out. If you are stuck on any step, you can scroll back up to Chip 1 to see what was done.
#
# But first, a little prediction: Without looking at your measured values, theorize as to whether Chip 2 will have more or less Calories per gram compared to Chip 1. You might want to consider factors like spice, flavor, weight, etc.

# %% [markdown]
# **<Replace this with your answer!>**

# %%
name_2 = ...

total_mass_2 = ...

serving_size_2 = ...

Cal_per_serving_2 = ...

initial_mass_2 = ...

final_mass_2 = ...

starting_temp_2 = ...

peak_temp_2 = ...

# %%
# Step 1

mass_burned_2 = ...
mass_burned_2

# %%
# Step 2

# assume m and c are the exact same for all trials (unless specified by the instructors)

delta_T_2 = ...

q_2 = ...

q_2

# %%
# Step 3

q_Cal_2 = ...
q_Cal_2

# %%
# Step 4

Cal_per_gram_2 = ...
Cal_per_gram_2

# %%
# Step 5

exp_Cal_per_serving_2 = ...
exp_Cal_per_serving_2

# %%
# Step 6

pct_error_2 = ...
pct_error_2

# %% [markdown]
# Did your prediction come true? Was your error higher or lower, and how could that have happened?

# %% [markdown]
# **<Replace this with your answer!>**

# %% [markdown]
# ## Chip 3
# As with Chip 2, predict how the Calories per gram of Chip 3 will compare with Chips 1 and 2.

# %% [markdown]
# **<Replace this with your answer!>**

# %%
name_3 = ...

total_mass_3 = ...

serving_size_3 = ...

Cal_per_serving_3 = ...

initial_mass_3 = ...

final_mass_3 = ...

starting_temp_3 = ...

peak_temp_3 = ...

# %%
# Step 1

mass_burned_3 = ...
mass_burned_3

# %%
# Step 2

# assume m and c are the exact same for all trials (unless specified by the instructors)

delta_T_3 = ...

q_3 = ...

q_3

# %%
# Step 3

q_Cal_3 = ...
q_Cal_3

# %%
# Step 4

Cal_per_gram_3 = ...
Cal_per_gram_3

# %%
# Step 5

exp_Cal_per_serving_3 = ...
exp_Cal_per_serving_3

# %%
# Step 6

pct_error_3 = ...
pct_error_3

# %% [markdown]
# How did the Third Chip go? Did it have the same or different calories per gram as your prediction? And as usual, was your error higher or lower, and how could that have happened?

# %% [markdown]
# **<Replace this with your answer!>**

# %% [markdown]
# # The End
# This marks the end of the Burning Food Lab. If you had measured more chips, insert cells above this one and carry out your calculations there. Which chip had the most calories per gram? Were you surprised by the result? Theorize as to what factors may cause a chip to have more or less calories per gram, and explain how your results support this theory.

# %% [markdown]
# **<Replace this with your answer!>**
