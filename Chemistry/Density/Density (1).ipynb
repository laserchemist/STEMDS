# %% [markdown]
# # Density Activity <font color = 'blue'>Version 1.1</font>
# Hello and Welcome to the Density Activity. I'll add more info here later.
#
# ## Directions:
# You and your group will conduct several experiments. In each experiment, you will be given a certain material.

# %%
# for the graphing and the mathing
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## Experiment #1:
#
# ### Step 1:
# First, make some observations on this material. What color is it? How does it feel?<br>Compare it to your previous measurements; would you predict it to be more or less dense, and why?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 2:
# Then, make different measurements of its mass and volume. (Replace the ...'s with your measurements.)

# %%
Material1_name = ...

# place all your MASS measurements here

Masses1 = np.array([..., ..., ..., ..., ...])

# place all your VOLUME measurements here
# (make sure their positions within the brackets match!)

Volumes1 = np.array([..., ..., ..., ..., ...])

# you can add more mass/volume measurements by continuing the pattern 
# (comma, then measurement, etc.)

# %%
# this cell will make a beautiful graph of your results. :)
# please do make sure there are no '...' left in the above lists

plt.scatter(Volumes1, Masses1)

# %% [markdown]
# How do the points look? Do they look like they all lie on a straight line?<br>Are there any outliers (points that do not make the trend of the rest) and if so, what could have caused them?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 3: Best Fit
# Refer to the file `Best Fit.ipynb` for guidance on how to calculate the best fit. You do not need to calculate R².
#
# Fee free to copy and paste the code from there in the cell below.

# %%
...

...

slope1 = ...

intercept1 = ...

# %% [markdown]
# ### Step 4: Best Fit: Intercept
# Now that you've found the slope, the equation $y = mx + b$ now only has one unknown value. Using your nifty algebra skills, rearrange the equation for $b$ and solve for it. Use the averages of x and y for the $x$ and $y$ in this equation.

# %%
intercept1 = ...
intercept1

# %% [markdown]
# Now, assuming you've assigned the slope and intercept to the relevant variable names, run this cell below to see your fit line in relation to the data. Does it look accurate?

# %%
plt.scatter(Volumes1, Masses1, color = 'black', label = 'actual data')
plt.plot(np.arange(0, max(Volumes1), max(Volumes1)/4), [slope1 * x + intercept1 for x in np.arange(0, max(Volumes1), max(Volumes1)/4)], color = 'red', label = 'fit line')
plt.legend()
plt.title('Mass of ' + Material1_name, ' as a Function of Volume')
plt.ylabel('Mass')
plt.xlabel('Volume')
plt.show()

# %% [markdown]
# ## Experiment #2:
#
# ### Step 1:
# First, make some observations on this material. What color is it? How does it feel?<br>Compare it to your previous measurements; would you predict it to be more or less dense, and why?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 2:
# Then, make different measurements of its mass and volume. (Replace the ...'s with your measurements.)

# %%
Material2_name = ...

# place all your MASS measurements here

Masses2 = np.array([..., ..., ..., ..., ...])

# place all your VOLUME measurements here
# (make sure their positions within the brackets match!)

Volumes2 = np.array([..., ..., ..., ..., ...])

# you can add more mass/volume measurements by continuing the pattern 
# (comma, then measurement, etc.)

# %%
# this cell will make a beautiful graph of your results. :)
# please do make sure there are no '...' left in the above lists

plt.scatter(Volumes2, Masses2)

# %% [markdown]
# How do the points look? Do they look like they all lie on a straight line?<br>Are there any outliers (points that do not make the trend of the rest) and if so, what could have caused them?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 3: Best Fit: Slope
#
# You can just copy and paste your cell from Experiment 1 here, and rename the variables as needed.

# %%
...

slope2 = ...

intercept2 = ...

# %% [markdown]
# Now, assuming you've assigned the slope and intercept to the relevant variable names, run this cell below to see your fit line in relation to the data. Does it look accurate?

# %%
plt.scatter(Volumes2, Masses2, color = 'black', label = 'actual data')
plt.plot(np.arange(0, max(Volumes2), max(Volumes2)/4), [slope2 * x + intercept2 for x in np.arange(0, max(Volumes2), max(Volumes2)/4)], color = 'red', label = 'fit line')
plt.legend()
plt.title('Mass of ' + Material2_name, ' as a Function of Volume')
plt.ylabel('Mass')
plt.xlabel('Volume')
plt.show()

# %% [markdown]
# ## Experiment #3:
#
# ### Step 1:
# First, make some observations on this material. What color is it? How does it feel?<br>Compare it to your previous measurements; would you predict it to be more or less dense, and why?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 3:
# Then, make different measurements of its mass and volume. (Replace the ...'s with your measurements.)

# %%
Material3_name = ...

# place all your MASS measurements here

Masses3 = np.array([..., ..., ..., ..., ...])

# place all your VOLUME measurements here
# (make sure their positions within the brackets match!)

Volumes3 = np.array([..., ..., ..., ..., ...])

# you can add more mass/volume measurements by continuing the pattern 
# (comma, then measurement, etc.)

# %%
# this cell will make a beautiful graph of your results. :)
# please do make sure there are no '...' left in the above lists

plt.scatter(Volumes3, Masses3)

# %% [markdown]
# How do the points look? Do they look like they all lie on a straight line?<br>Are there any outliers (points that do not make the trend of the rest) and if so, what could have caused them?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 3: Best Fit: Slope
#
# You can just copy and paste your cell from Experiment 1/2 here, and rename the variables as needed.

# %%
...

slope3 = ...

intercept3 = ...

# %% [markdown]
# Now, assuming you've assigned the slope and intercept to the relevant variable names, run this cell below to see your fit line in relation to the data. Does it look accurate?

# %%
plt.scatter(Volumes3, Masses3, color = 'black', label = 'actual data')
plt.plot(np.arange(0, max(Volumes3), max(Volumes3)/4), [slope3 * x + intercept3 for x in np.arange(0, max(Volumes3), max(Volumes3)/4)], color = 'red', label = 'fit line')
plt.legend()
plt.title('Mass of ' + Material3_name, ' as a Function of Volume')
plt.ylabel('Mass')
plt.xlabel('Volume')
plt.show()

# %% [markdown]
# ## Conclusion
# Take a look at the output of the following cell.

# %%
print(f'The graph of {Material1_name} has a slope of {slope1:2f} and an intercept of {intercept1:2f}')
print(f'The graph of {Material2_name} has a slope of {slope2:2f} and an intercept of {intercept2:2f}')
print(f'The graph of {Material3_name} has a slope of {slope3:2f} and an intercept of {intercept3:2f}')

# %% [markdown]
# Which of the two values is most indicative of the density?

# %% [markdown]
# **<Replace this line with your answer!>**

# %%
plt.scatter(Volumes1, Masses1, label = Material1_name)
plt.plot(np.arange(0, max(Volumes1), max(Volumes1)/4), [slope1 * x + intercept1 for x in np.arange(0, max(Volumes1), max(Volumes1)/4)], label = 'fit line of '+Material1_name)

plt.scatter(Volumes2, Masses2, label = Material2_name)
plt.plot(np.arange(0, max(Volumes2), max(Volumes2)/4), [slope2 * x + intercept2 for x in np.arange(0, max(Volumes2), max(Volumes2)/4)], label = 'fit line of '+Material2_name)

plt.scatter(Volumes3, Masses3, label = Material3_name)
plt.plot(np.arange(0, max(Volumes3), max(Volumes3)/4), [slope3 * x + intercept3 for x in np.arange(0, max(Volumes3), max(Volumes3)/4)], label = 'fit line of '+Material3_name)

# %% [markdown]
# Make observations about these different results.
# * How do the materials of higher density compare to those of lower density?
# * Where do these lines meet up? What is the physical meaning of this point?

# %% [markdown]
# **<Replace this line with your answer!>**
