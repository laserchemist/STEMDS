# %% [markdown]
# # Density Activity <font color = 'blue'>Version 1.2</font>
#
# Hello and Welcome to your first lab here in STEM-UP! You'll complete this alongisde the density measurements.
#
# ## Directions:
# You and your group will conduct several experiments. In each experiment, you will be given a certain material.

# %%
# for the graphing and the mathing
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from bestfit import *

# %% [markdown]
# ## Experiment #1:
#
# ### Step 1:
# First, make some observations on this material. What color is it? How does it feel?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 2:
# Then, make different measurements of its mass and volume. (Replace the ...'s with your measurements.) Don't include the units.

# %%
# put the name of your material here (surround it in quotes)

Material1_name = ...

data1 = [
    # volumes       # mass
    [...       ,      ...], # first measurement
    [...       ,      ...], # second measurement
    [...       ,      ...], # third measurement
    [...       ,      ...]] # fourth measurement

# don't touch the parts below this

Volumes1 = [i[0] for i in data1]
Masses1 = [i[1] for i in data1]

# %%
# this cell will make a beautiful graph of your results. :)
# please do make sure there are no '...' left in the above lists

# (if this doesn't show a graph or error, scroll back up and rerun the import cells)

plt.scatter(Volumes1, Masses1)

plt.title('Mass of '+Material1_name+' as a function of Volume')

plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')

plt.show()

# %% [markdown]
# How do the points look? Do they look like they all lie on a straight line?<br>Are there any outliers (points that do not match the trend of the rest) and if so, what could have caused them?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 3: Best Fit
# We'll provide the functions for the Best Fit (your `Volumes1` are the `x_array`, and your `Masses1` are the `y_array`):
#
# <code>slope(**x_array**, **y_array**)</code>
#
# <code>intercept(**x_array**, **y_array**)</code>

# %%
slope1 = ...

intercept1 = ...

# %% [markdown]
# Now, assuming you've assigned the slope and intercept to the relevant variable names, run this cell below to see your fit line in relation to the data. Does it look accurate?

# %%
plt.scatter(Volumes1, Masses1, color = 'black', label = 'actual data')
xline1 = np.arange(min(Volumes1), max(Volumes1)+1, np.ptp(Volumes1)/20)
plt.plot(xline1, xline1*slope1+intercept1, color = 'red', label = 'fit line')
plt.legend()
plt.title('Relationship between the Mass and Volume of '+Material1_name+' with best fit line')

plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')

plt.show()

# %% [markdown]
# We can mathematically assess the validity of our fit line through the $r^2$ value.
#
# The code below will get you the $r$ value (not squared). Use the necessary math operations to get $r^2$.
#
# <code>correlation(**x_array**, **y_array**)</code>

# %%
r_1 = ...

r2_1 = ...
r2_1

# %% [markdown]
# An $r^2$ value closer to 1 denotes a more accurate fit. How accurate is your fit? Is there anything that occurred during the experiment that may have altered the accuracy?
#
# **<Replace this line with your answer!>**

# %% [markdown]
# ## Experiment #2:
#
# ### Step 1:
# First, make some observations on this material. What color is it? How does it feel?<br>Compare it to your previous measurements; would you predict it to be more or less dense, and why?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 2:
# Then, make different measurements of its mass and volume. (Replace the ...'s with your measurements.) Don't include the units.

# %%
# put the name of your material here (surround it in quotes)

Material2_name = ...

data2 = [
    # volumes       # mass
    [...       ,      ...], # first measurement
    [...       ,      ...], # second measurement
    [...       ,      ...], # third measurement
    [...       ,      ...]] # fourth measurement

# don't touch the parts below this

Volumes2 = [i[0] for i in data2]
Masses2 = [i[1] for i in data2]

# %%
# this cell will make a beautiful graph of your results. :)
# please do make sure there are no '...' left in the above lists

plt.scatter(Volumes2, Masses2)

plt.title('Mass of '+Material2_name+' as a function of Volume')

plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')

plt.show()

# %% [markdown]
# How do the points look? Do they look like they all lie on a straight line?<br>Are there any outliers (points that do not match the trend of the rest) and if so, what could have caused them?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 3: Best Fit
# Use the same code that you had used in the first experiment to get the slope and intercept.

# %%
slope2 = ...

intercept2 = ...

# %% [markdown]
# Now, assuming you've assigned the slope and intercept to the relevant variable names, run this cell below to see your fit line in relation to the data. Does it look accurate?

# %%
plt.scatter(Volumes2, Masses2, color = 'black', label = 'actual data')
xline2 = np.arange(min(Volumes2), max(Volumes2)+1, np.ptp(Volumes2)/20)
plt.plot(xline2, xline2*slope2+intercept2, color = 'red', label = 'fit line')
plt.legend()
plt.title('Relationship between the Mass and Volume of '+Material2_name+' with best fit line')

plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')

plt.show()

# %% [markdown]
# Get the $r^2$ value for this second best fit line.

# %%
r_2 = ...

r2_2 = ...
r2_2

# %% [markdown]
# An $r^2$ value closer to 1 denotes a more accurate fit. How accurate is your fit? Is there anything that occurred during the experiment that may have altered the accuracy?
#
# **<Replace this line with your answer!>**

# %% [markdown]
# ## Experiment #3:
#
# ### Step 1:
# First, make some observations on this material. What color is it? How does it feel?<br>Compare it to your previous measurements; would you predict it to be more or less dense, and why?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 2:
# Then, make different measurements of its mass and volume. (Replace the ...'s with your measurements.) Don't include the units.

# %%
# put the name of your material here (surround it in quotes)

Material3_name = ...

data3 = [
    # volumes       # mass
    [...       ,      ...], # first measurement
    [...       ,      ...], # second measurement
    [...       ,      ...], # third measurement
    [...       ,      ...]] # fourth measurement

# don't touch the parts below this

Volumes3 = [i[0] for i in data3]
Masses3 = [i[1] for i in data3]

# %%
# this cell will make a beautiful graph of your results. :)
# please do make sure there are no '...' left in the above lists

plt.scatter(Volumes3, Masses3)

plt.title('Mass of '+Material3_name+' as a function of Volume')

plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')

plt.show()

# %% [markdown]
# How do the points look? Do they look like they all lie on a straight line?<br>Are there any outliers (points that do not match the trend of the rest) and if so, what could have caused them?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 3: Best Fit
# You've probably got this under your fingers by now.

# %%
slope3 = ...

intercept3 = ...

# %% [markdown]
# Now, assuming you've assigned the slope and intercept to the relevant variable names, run this cell below to see your fit line in relation to the data. Does it look accurate?

# %%
plt.scatter(Volumes3, Masses3, color = 'black', label = 'actual data')
xline3 = np.arange(min(Volumes3), max(Volumes3)+1, np.ptp(Volumes3)/20)
plt.plot(xline3, xline3*slope3+intercept3, color = 'red', label = 'fit line')
plt.legend()
plt.title('Relationship between the Mass and Volume of '+Material3_name+' with best fit line')

plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')

plt.show()

# %% [markdown]
# Finally, the $r^2$ value for the third best fit line.

# %%
r_3 = ...

r2_3 = ...
r2_3

# %% [markdown]
# An $r^2$ value closer to 1 denotes a more accurate fit. How accurate is your fit? Is there anything that occurred during the experiment that may have altered the accuracy?
#
# **<Replace this line with your answer!>**

# %% [markdown]
# ## Experiment #4:
#
# ### Step 1:
# First, make some observations on this material. What color is it? How does it feel?<br>Compare it to your previous measurements; would you predict it to be more or less dense, and why?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 2:
# Then, make different measurements of its mass and volume. (Replace the ...'s with your measurements.) Don't include the units.

# %%
# put the name of your material here (surround it in quotes)

Material4_name = ...

data4 = [
    # volumes       # mass
    [...       ,      ...], # first measurement
    [...       ,      ...], # second measurement
    [...       ,      ...], # third measurement
    [...       ,      ...]] # fourth measurement

# don't touch the parts below this

Volumes4 = [i[0] for i in data4]
Masses4 = [i[1] for i in data4]

# %%
# this cell will make a beautiful graph of your results. :)
# please do make sure there are no '...' left in the above lists

plt.scatter(Volumes4, Masses4)

plt.title('Mass of '+Material4_name+' as a function of Volume')

plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')

plt.show()

# %% [markdown]
# How do the points look? Do they look like they all lie on a straight line?<br>Are there any outliers (points that do not match the trend of the rest) and if so, what could have caused them?

# %% [markdown]
# **<Replace this line with your answer!>**

# %% [markdown]
# ### Step 3: Best Fit
# You've probably got this under your fingers by now.

# %%
slope4 = ...

intercept4 = ...

# %% [markdown]
# Now, assuming you've assigned the slope and intercept to the relevant variable names, run this cell below to see your fit line in relation to the data. Does it look accurate?

# %%
plt.scatter(Volumes4, Masses4, color = 'black', label = 'actual data')
xline4 = np.arange(min(Volumes4), max(Volumes4)+1, np.ptp(Volumes4)/20)
plt.plot(xline4, xline4*slope4+intercept4, color = 'red', label = 'fit line')
plt.legend()
plt.title('Relationship between the Mass and Volume of '+Material4_name+' with best fit line')

plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')

plt.show()

# %% [markdown]
# Finally, the $r^2$ value for the third best fit line.

# %%
r_4 = ...

r2_4 = ...
r2_4

# %% [markdown]
# An $r^2$ value closer to 1 denotes a more accurate fit. How accurate is your fit? Is there anything that occurred during the experiment that may have altered the accuracy?
#
# **<Replace this line with your answer!>**

# %% [markdown]
# ## Conclusion
# Take a look at the output of the following cell.

# %%
print(f'The graph of {Material1_name} has a slope of {slope1:2f} and an intercept of {intercept1:2f}')
print(f'The graph of {Material2_name} has a slope of {slope2:2f} and an intercept of {intercept2:2f}')
print(f'The graph of {Material3_name} has a slope of {slope3:2f} and an intercept of {intercept3:2f}')
print(f'The graph of {Material4_name} has a slope of {slope4:2f} and an intercept of {intercept4:2f}')

# %% [markdown]
# Which of the two values is most indicative of the density?

# %% [markdown]
# **<Replace this line with your answer!>**

# %%
plt.scatter(Volumes1, Masses1, label = Material1_name)
plt.plot(xline1, xline1*slope1+intercept1, label = 'fit line of '+Material1_name)

plt.scatter(Volumes2, Masses2, label = Material2_name)
plt.plot(xline2, xline2*slope2+intercept2, label = 'fit line of '+Material2_name)

plt.scatter(Volumes3, Masses3, label = Material3_name)
plt.plot(xline3, xline3*slope3+intercept3, label = 'fit line of '+Material3_name)

plt.scatter(Volumes4, Masses4, label = Material4_name)
plt.plot(xline4, xline4*slope4+intercept4, label = 'fit line of '+Material4_name)

plt.legend()

plt.title('Data and Fit Lines from All Four Experiments')
plt.xlabel('Volume (mL)')
plt.ylabel('Mass (g)')
plt.show()

# %% [markdown]
# Make observations about these different results.
# * How do the materials of higher density compare to those of lower density?
# * Where do these lines meet up? What is the physical meaning of this point?

# %% [markdown]
# **<Replace this line with your answer!>**
