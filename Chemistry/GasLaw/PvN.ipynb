# %% [markdown]
# # Gas Law PostLab: Pressure vs. Amount of Molecules <font color = 'blue'>Version 1.0</font>

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# This lab covers the Second part of the Gas Law experiment. There will be three parts, the current one being highlighted in bold:
# * Pressure vs. Volume
# * **Pressure vs. Amount of Gas Molecules**
# * Pressure vs. Temperature
#
# Much like how a tree starts with a seed, good science always begins with data. Use the code cells below to import your data.

# %%
PvN_data = ...

# %% [markdown]
# Before we start, it helps to think about what's happening in the setup. Using what you know about pressure and molecules, what did you predict would happen to the pressure as the amount of gas molecules increased/decreased? Is this trend reflected in your data/observations?
#
# **<Replace this line with your answer!>**

# %% [markdown]
# ## Step 1: Identify the Trend
# Take a look at your beautiful data and graph the pressure column against the molecules column.

# %%
PvN_data # to help you determine where the columns are

# %%
# helps to define the column arrays as their own variables.
pressure = ...
gas_amount = ...

# graph the pressure as y and amount of gas molecules as x
...

# %% [markdown]
# Take a look at the shape that your data makes, and compare it to the shapes of the following graphs below.

# %%
# don't modify this part
sample_data = np.arange(0.1, 5, 0.2)
print(len(sample_data))

# your choices
Linear = sample_data              # y = a * x
Polynomial = sample_data**2       # y = a * x**b (much simplified)
Inverse = 1/sample_data           # y = a / x
Root = np.sqrt(sample_data)       # y = a * x**(1/b)

# %%
plt.plot(sample_data, Linear) # modify the SECOND argument to be any of the 4 choices above

# %% [markdown]
# Which of these shapes most closely resembles the data?
#
# **<Replace this line with your answer!>**
#
# This will affect what you do in Step 2.

# %% [markdown]
# ## Step 2: Adjust the X-axis (Only do this if you have identified a non-linear relationship)
# If the relationship between pressure and amount of gas molecules seems to be linear, that is wonderful! ;) You can skip Step 2. (Do still run these cells, just leave the cells unchanged.)
#
# Anyways, if you're still here I assume you have a NON-linear relationship. If we want to get a trend for any relatonship that is not linear, it becomes hard and tedious extremely fast. However! we can turn a non-linear relationship into a linear one by replacing some part of the equation with a new variable, which we'll call $z$.
#
# |If your relationship is...|Then the general formula is...|But we can define $z$ as...|And that turns the formula into...|
# |--|--|--|--|
# |Linear|$y=ax$|Hey, why are you still on this step???|>:(|
# |Polynomial|$y=ax^b$|$z = x^b$|$y=az$|
# |Inverse|$y=a/x$|$z=1/x$|$y=az$|
# |Root|$y=ax^{1/b}$|$z=x^{1/b}$|$y=az$|
#
# Use the chart to figure out what to define $z$ as, and then carry out the necessary calculations to make $z$.

# %%
z = ...

# %% [markdown]
# Now, graph $z$ on the x-axis and the pressure on the y-axis. It should look more like a linear graph.

# %%
...

# %% [markdown]
# ## Step 3: Get the Linear Relationship
# To those who have a linear relationship, welcome back!
#
# Now, we will do the same thing that we had done in the Density lab, that is, get a best fit line of the data. You are welcome to use the same lines of code from the Density lab or the Best Fit Activity (though you should change the variable names to suit this lab).
#
# You will need a slope and intercept to continue to Step 4. You can also calculate R², but that isn't required.

# %%
...

slope = ...

intercept = ...

# %% [markdown]
# Take a look at the following cell: (IF you had a Nonlinear relationship, look for the `...` below and replace it with what you defined `z` as (NOT `z` itself!).

# %%
# this is a VERY complex structure; you won't need this for your own coding. (though you are free to study it)

try:
    test = z+1
except TypeError as error:
    plt.scatter(gas_amount, pressure, label = 'data')
    plt.plot([min(gas_amount), max(gas_amount)], [slope * min(gas_amount) + intercept, slope * max(gas_amount) + intercept], label = 'fit line')
    plt.title('Linear Fit of Pressure vs. Amount of Gas Molecules')
    plt.xlabel('Amount of Gas Molecules')
    plt.ylabel('Pressure')
    plt.legend()
    plt.show()
else:
    plt.scatter(z, pressure, label = 'data')
    plt.plot([min(z), max(z)], [slope * min(z) + intercept, slope * max(z) + intercept], label = 'fit line')
    plt.title('Linear Fit of Pressure vs. Modified Amount of Gas Molecules')
    plt.xlabel('Modified Amount of Gas Molecules')
    plt.ylabel('Pressure')
    plt.legend()
    plt.show()
    plt.figure()
    plt.scatter(gas_amount, pressure, label = 'data')
    plt.plot(np.arange(min(gas_amount), max(gas_amount), np.ptp(max(gas_amount) - min(gas_amount))/30), slope * (...) + intercept, label = 'fit line')
    plt.title('Fit of Pressure vs. Amount of Gas Molecules (Original Data Values)')
    plt.xlabel('Amount of Gas Molecules')
    plt.ylabel('Pressure')
    plt.legend()
    plt.show()

# %% [markdown]
# How does the relationship look? Is it accurate?
#
# Now may be a good time to consult with a TA as to what the actual relationship is. If you were not correct, what could have caused this discrepancy?
#
# **<Replace this with your answer!>**
