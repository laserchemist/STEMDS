# %% [markdown]
# # Gas Law PostLab: Pressure vs. Volume <font color = 'blue'>Version 1.1</font>

# %%
import numpy as np
from datascience import *
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
from bestfit import *

# %% [markdown]
# This lab covers the First part of the Gas Law experiment. There will be three parts, the current one being highlighted in bold:
# * **Pressure vs. Volume**
# * Pressure vs. Number of Gas Molecules
# * Pressure vs. Temperature
#
# Much like how a car starts with an engine, good science always begins with data. Use the code cells below to import your data.

# %%
PvV_data = ...

# %% [markdown]
# Before we start, it helps to think about what's happening in the setup. Using what you know about pressure and volume, what did you predict would happen to the pressure as the volume increased/decreased? Is this trend reflected in your data/observations?
#
# **<Replace this line with your answer!>**

# %% [markdown]
# ## Step 1: Identify the Trend
# Take a look at your beautiful data and graph the pressure column against the volume column.

# %%
PvV_data # to help you determine where the columns are

# %%
# extract the pressures and volumes as arrays.
pressure = ...
volume = ...

# this will graph the pressure as y and volume as x
plt.scatter(volume, pressure)

plt.xlabel('Volume (mL)')
plt.ylabel('Pressure (kPa)')
plt.title('Pressure as a Function of Volume')

# %% [markdown]
# Take a look at the shape that your data makes, and compare it to the shapes of the following graphs below.

# %%
# don't modify this part
sample_data = np.arange(0.1, 5, 0.2)

# your choices
Linear = sample_data              # y = a * x
Power = sample_data**2       # y = a * x**2 (will just use square)
Inverse = 1/sample_data           # y = a / x
Root = np.sqrt(sample_data)       # y = a * x**(1/2) (will just use square root)

# %%
plt.plot(sample_data, ...) # modify the SECOND argument to be any of the 4 choices above

# %% [markdown]
# Which of these shapes most closely resembles the data?
#
# **<Replace this line with your answer!>**
#
# This will affect what you do in Step 2.

# %% [markdown]
# ## Step 2: Adjust the X-axis (Only do this if you have identified a non-linear relationship)
# If the relationship between pressure and volume seems to be linear, that is wonderful! ;) You can skip Step 2. (Do still run these cells, just leave the cells unchanged.)
#
# Anyways, if you're still here I assume you have a NON-linear relationship. If we want to get a trend for any relatonship that is not linear, it becomes hard and tedious extremely fast. However! we can turn a non-linear relationship into a linear one by replacing some part of the equation with a new variable, which we'll call $z$.
#
# |If your relationship is...|Then the general formula is...|But we can define $z$ as...|And that turns the formula into...|
# |--|--|--|--|
# |Linear|$y=ax$|Hey, why are you still on this step???|>:(|
# |Power|$y=ax^2$|$z = x^2$|$y=az$|
# |Inverse|$y=a/x$|$z=1/x$|$y=az$|
# |Root|$y=ax^{1/2}$|$z=x^{1/2}$|$y=az$|
#
# Use the chart to figure out what to define $z$ as, and then carry out the necessary calculations to make $z$.

# %%
z = ...

# %% [markdown]
# Now, graph $z$ on the x-axis and the pressure on the y-axis. It should look more like a linear graph.

# %%
...

# %% [markdown]
# ## Step 3: Get the Linear Relationship
# To those who have a linear relationship, welcome back!
#
# * If you have a linear relationship, get the slope and intercept of **volume** and **pressure**.
# * However, if you have a nonlinear relationship, get the slope and intercept of **z** and **pressure**.
#
# To get the slope and intercept, we have provided you with easy-to-use functions (replace the bolded parts with your variables):
#
# <code>slope(**x_array**, **y_array**)</code>
#
# <code>intercept(**x_array**, **y_array**)</code>

# %%
slope = ...

intercept = ...

print('The value of the slope is', slope, 'and the value of the intercept is', intercept)

# %% [markdown]
# There is a value called $r^2$, which assesses how close the best fit line is to the actual data.
#
# You can get $r$ (not squared) from <code>correlation(**x_array**, **y_array**)</code>. Use math to get $r^2$ from that.

# %%
r = ...

r2 = ...

r2

# %% [markdown]
# An $r^2$ value closer to 1 denotes a more accurate fit, whereas a value closer to 0 denotes a less accurate fit. How well do the slope and intercept match the actual data?
#
# **<Replace this with your answer!>**

# %% [markdown]
# ## Final Visualizations

# %% [markdown]
# Take a look at the following cell. If you had a Nonlinear relationship, change the `'Linear'` accordingly.

# %%
originalGrapher(slope, intercept, PvV_data, PvV_data.labels[0], PvV_data.labels[1], 'Linear')

# %% [markdown]
# How does the relationship look? Is it accurate?
#
# Now may be a good time to consult with a TA as to what the actual relationship is. If you were not correct, what could have caused this discrepancy?
#
# **<Replace this with your answer!>**
