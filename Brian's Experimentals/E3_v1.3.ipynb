# %% [markdown]
# # Exercises for Lab 03 <font color=blue>Version 1.3 </font>

# %% [markdown]
# Hello and Welcome to the Exercises for Lab 3! Much like in other versions of the Exercises, we are going by the assumption that you have been keeping up with compiling all the different functions and methods in your library. Thus, this Exercise will focus much more on when you should use which function/method, and getting these methods properly integrated into your coding vocabulary.

# %%
from datascience import *
import numpy as np # this library is also used in these Exercises.

# %% [markdown]
# ## Exercise 1: Breaking the Ice
# Tips:
# * **Tables as an Organizational Tool:** The main benefit of tables is that they are unfailingly faithful at pairing values together. If two values are in the same row, they will be in the same row no matter what method you throw at it. Use this to your advantage!
# * **Table rows as single observations:** In statistics, an 'observation' refers to a singular piece of data. For the imdb table, a single movie is an observation, and all the qualities (e.g. name, rating, votes) of that single movie are stored in a row of the table. Thus, when you see the imdb table having 250 rows, you can be sure that it has 250 movies.
# * **Watch for keywords:** Much like how 'sum', ' total', 'combination' imply addition, there are some words that lend naturally to using a certain method. This has to do with the nature of the method itself and the kinds of values it deals best with. Such natures and values are listed below.
#
# |Method|Purpose|Keyword (Example for imdb Table)|
# |--|--|--|
# `.sort`|**Formatting:** It is used to get extreme values, that is, the largest/smallest. It is the go-to for this, *as well as* getting values in the same row as the largest/smallest.|'What is the largest number of votes recorded?' and 'What is the Movie Title with the largest number of votes?'|
# |`.where`|**Formatting:** It is used to get any rows that match the given conditional, regardless of any other qualities.|'What movies have votes above 500K?' and 'What movies were released prior to the 21st century?'|
# |`.num_rows`|**Extraction/Data Analysis:** Useful in that rows in tables almost always refer to a single 'observation' or 'object' of the dataset. The number of rows in the table corresponds to the number of observations (in the imdb case, movies). Used often with a filtered table.|Just add 'How many' before any question, e.g. 'How many movies/markets have votes above 500K?'|
# |`.column`, or its related index form (see the toolbox)|**Extraction/Data Analysis:** The only way you can get arrays (or single values associated with those arrays) out of a table. Used further with statistical functions.|You will need this if you want to store any answer to a question under a variable. For example, 'Store the Movie with the most votes as a string.'<br>Also relevant are the functions that only take in a list/array. 'What is the average rating of all the movies?' and 'What is the standard deviation in the Votes?'|
#
# Finally, always remember that your means of analysis are hindered most pertinently by the data itself. You can't analyze the movies' box office earnings, for example, because that just isn't part of the dataset. However, even parts of the dataset that are related to existing values (like the number of words/characters in the title, or the number of movies released in each decade) are unable to be analyzed until the necessary adjustments showing this are added. We'll look at this in Parts 3 and 4.

# %% [markdown]
# ### 1.1:
# We'll use the `imdb.csv` table for this Exercises 1. Use the relevant method to get the table.

# %% [markdown]
# ### 1.2:
# How many movies have a rating between 8 and 9?
#
# It may help to list out the methods that you will need to format the table and extract the desired information. I've done this below as an example, but you may want to do the same for the rest of Exercise 1.
#
# Formatting Methods: `.where` (filtering) with `are.between` conditional
#
# Extraction/Data Analysis Methods: `num_rows` (each row counts as a movie) (you can alternatively do `.column` and `len`)

# %% [markdown]
# ### 1.3:
# What's the Average Rating of Movies in the 2010s?
#
# Formatting Methods: **answer here**
#
# Extraction/Data Analysis Methods: **answer here**

# %% [markdown]
# ### 1.4:
# What's the movie with the most votes?
#
# Formatting Methods: **answer here**
#
# Extraction/Data Analysis Methods: **answer here**

# %% [markdown]
# ## Exercise 2: More Practice
# Alright, given the importance that Tables hold in this course, and given the absolute *barrage* of Table methods you just endured, it's imperative that you get lots of practice with this. Namely, you need to be able to turn English questions about the dataset into actual code that answers said question. Each part features 3 questions, each of which you should be able to answer in around 3-4 lines of code, and a challenge question, which requires much more effort.

# %% [markdown]
# ### 2.1: World Populations
# These questions regard the dataset 'world_populations.csv'. I've already loaded it up for you. :)

# %%
pops = Table.read_table('world_population.csv')
pops = pops.with_column('Year', np.arange(1950, 2016))
pops

# %% [markdown]
# How many years did the world spend with a population between 4 and 5 billion?

# %% [markdown]
# Has the world population grown a larger amount from 1950 to 2000 or from 2000 to 2015? By how much are these amounts different?

# %% [markdown]
# In what year did the population cross 6 billion?

# %% [markdown]
# Challenge: Which year saw the greatest CHANGE in populations?

# %% [markdown]
# ### 2.2: Farmers Markets
# These questions regard the dataset 'farmers_markets.csv'.

# %%
farmers_markets = Table().read_table('farmers_markets.csv')
farmers_markets = farmers_markets.drop('FMID','Website','Facebook','Twitter','Youtube','OtherMedia','Season1Date','Season1Time','Season2Date','Season2Time','Season3Date','Season3Time','Season4Date','Season4Time')
farmers_markets

# %% [markdown]
# What percentage of these markets have 'Farmers' in their name?

# %% [markdown]
# What markets lie within 1 degree, latitude and longitude, of the Temple University's SERC building (the coordinates are -75.153, 39.982)? For reference, one degree of latitude/longitude is equal to 69 miles. (nice)

# %% [markdown]
# What markets sell Meat and Tofu but no vegetables?

# %% [markdown]
# Challenge: Which market rows were updated the latest? (This would normally be pretty feasible except some market rows don't follow the dominant format; you may want to assume that they were simply updated very early on (and can thus be filtered out), but how can you use code to definitively show that?)

# %% [markdown]
# ### 2.3: Yale EPI
# These questions regard the dataset 'yale_epi.csv'. I'll leave it to you to create this one.

# %% [markdown]
# What rank is the country whose score *decreased* the most (NOT whose score is the least)?

# %% [markdown]
# What is the average Change that occured across the decade by all 180 countries?

# %% [markdown]
# Which country had the LEAST change (not moving much in both the positive and negative directions)?

# %% [markdown]
# Challenge: Which country had the greatest increase *as a percentage of their original score*?

# %% [markdown]
# ## Exercise 3: Data Manipulation
# A central part of data manipulation is, well, the manipulation of data (well done Einstein). This primarily constitutes the use of FOM (Functions, Operations, and/or Methods) to show another aspect of data or to express existing data in a different format.
#
# Why do we want to manipulate data?
# * To remake it in a format that is more easily usable by the computer itself (Remember, your capabilities in analyzing data are determined at least partially by the capabilities of Python itself!)
# * To conduct statistical tests and other advanced actions (spoilers for Lab 05 and onwards)
#
# The principal way to manipulate data is to extract it from the Table setting. While it may seem that Tables are the all-important focus of this class, don't fall for that illusion. **Tables are only a convenient way to organize and understand data. By themselves, they are incapable of actual analysis.** The true leaders here are the lists and arrays. I'll leave it to you to find the exact method that converts tables to arrays in the above table.

# %% [markdown]
# ### 3.1: Title Length
# If you haven't already, create the imdb Table from the file named 'imdb.csv'. Extract the Title column as an array.

# %% [markdown]
# Use the relevant command, and the correct format, to get a list that contains the number of characters in each title. For example, the movie title 'León' would beget a value of 4 (it has 4 characters). Review the Exercises 02 if you do not know.

# %% [markdown]
# Append this column to the imdb table. Give it any column header you want. :']

# %% [markdown]
# What are the five movies with the longest names?

# %% [markdown]
# ### 3.2: Date Formatting
# Now time for some actually-real-world applications. A very common sight in Tables and Data Statistics in general is the reformatting of dates to render them more code-oriented. After all, Python has no idea what the slashes in '7/31/2025' mean, nor does it comprehend the colons in '6:30:25'. To be able to work with times and dates, we need to reexpress these values in terms of a single unit (e.g. hours) instead of multiple units (e.g. hours : minutes : seconds).
#
# Consider the times in the following table. Our task in this exercise is to convert them from hh:mm:ss to some amount of hours past midnight. For example, a time of 11:30:00 gets a value of 11.5 hours past midnight, and 7:25:52 gets a value of 7.431 hours past midnight. In essence, we are doing the following: (using 15:35:20 as an example)
# 1. Getting the seconds in terms of a decimal portion of a minute (e.g. 20 seconds is 1/3 of a minute or 0.33 minutes)
# 2. Adding that to the minute count (35+0.33 = 35.33 minutes)
# 3. Expressing that minute count in terms of a decimal portion of an hour (35.33 minutes becomes 0.589 hours)
# 4. Adding that to the hours (15+0.589 = 15.589 hours)

# %%
unformatted = ["4:50:31", "7:12:45", "9:38:09", "11:27:56", "13:03:22", "15:41:10", "17:19:44", "20:02:37", "22:46:05", "00:15:28"]

times = Table().with_columns('hh:mm:ss times', unformatted)
times # this is typically what these times will look like within a table. 
# Of course, other data will also be there, but for the sake of simplicity, this is not included.

# %% [markdown]
# When having to format a whole list, it's a good idea to focus solely on one singular value, and then extrapolate to the entire thing. Try working with just this first value below.

# %%
test_time = times[0][0]
test_time

# %% [markdown]
# Here are some guiding questions:
# * How do you 'unpack' the values in the data format?
# * Are these unpacked values able to be worked with numerically? What do you have to do to make them so?
# * Once you have have worked it out and gotten the singular test_time to work, what do you have to do to apply this to the whole table column?
# * Remember, what first step do you have to do to make data within tables open to analysis?
#
# Once you've solved it, append the formatted times as another column to the table.

# %% [markdown]
# ## Exercise 4: The Holy Grail of Statistical Methods
# ### 4.1:
# In this section, we will introduce to ourselves a very useful function whose name I will not spoil yet. This involves the use of the farmers_markets table. If you look at the bunch of columns at the far right end, most of them show whether or not a given market sells a particular good. A 'Y' means that the market does sell it, and 'N' means that it doesn't.

# %%
farmers_markets

# %% [markdown]
# Suppose you pick the Cheese column (because I like cheese) that has these Ys and Ns and want to know how many of them have Ys (how many sell cheese) and how many of them have Ns (how many don't sell cheese). (Note that Ys and Ns are the only inputs in the column.) How do you do this?

# %% [markdown]
# Step 1: Define the `Y_cheese` variable as the farmers_markets table containing only the rows with 'Y' in the Cheese column, and the `N_cheese` variable as the table containing only the rows with 'N' in the Cheese column.

# %% [markdown]
# Step 2: Get the number of rows in the Y_cheese and N_cheese, and define them as `Y_rows` and `N_rows`.

# %% [markdown]
# Note that what you've gotten right now, in Y_rows and N_rows, is the number of markets that have cheese (number of rows that have 'Y') and don't have cheese (number of rows that have 'N'). Now, assuming you've done your duty in properly defining these variables, I'll package this information in a format that is much more pleasant to your eyes.

# %%
# don't change this cell!
inputs = ['Y', 'N']
number_rows = [Y_rows, N_rows]
summary_cheese = Table().with_columns('Cheese', inputs, 'count', number_rows)
summary_cheese = summary_cheese.sort('Cheese')
summary_cheese

# %% [markdown]
# This is the essence of our mystery function: for each unique element in a given column, it will tell you how many rows in the table have that input for that column. Here is that mystery function below.

# %%
farmers_markets.group('Cheese')

# %% [markdown]
# ### 4.2: Practice with `.group`
# Which 5 states have the most markets?

# %% [markdown]
# Going back to the imdb table, what's the *range* in the number of movies released each decade?

# %% [markdown]
# What rating was the most common? Define your .group table as `imdb_ratings`.
#
# Note that, since the .group method gives you a table, you can modify that table in itself. Use this fact to add on to `imdb_ratings` another column that tells you what percentage of the total movies had that rating.

# %% [markdown]
# ### 4.3: `.group` with a function
# When paired with a function as the second argument, the resultant table is very different. Let's look back at the imdb table, and apply the .group method and the np.average function to the 'Decade' column. It does filter the table according to each unique input of Decade, but instead of taking the number of rows for each input in Decade, it looks at the other columns besides Decade and takes their average (applies the specified function).

# %%
imdb.group('Decade', np.average)

# %% [markdown]
# Let's take the first row as an example.
#
# What it tells us is that, for all the 1920 movies in the table...
# * They got 64854 votes on average
# * They had an average rating of 8.25
# * The average year in which they were released was 1924 (ignoring decimals)
# * They had an average of 0.25 A's in their name.
#
# And this goes for all the movies released in the decade of 1920. The 1930 movies' average stats are in the second row, the 40s' stats in the third, and so forth.
#
# Note that the Title column is blank because you can't take the average of non-numerical values.

# %% [markdown]
# **What functions can you use in `.group`?**
#
# Any function works SO LONG AS its only input is a list or array. Methods do not work, as the .group assumes that this only input is in the parentheses following the function name, and the method's input is before it.

# %% [markdown]
# What decade had the longest-titled movie names?

# %% [markdown]
# What's the westernmost market that sells Eggs?

# %% [markdown]
# ## Exercise 5: Pivot
# A function that is similar to .group is .pivot, where the resultant table denotes how many rows have TWO indicated elements in TWO columns. Take a look at the table formed by this following cell.

# %%
imdb.pivot('Rating', 'Decade')

# %% [markdown]
# Looking at the first row, it tells us that, among the 1920 movies, 2 of them scored an 8.2. That is, there were two rows that simultaneously had a value of 1920 for the decade and 8.2 for the rating.
#
# Note the input order; the column elements on the headers correspond to the FIRST input, and those on the side axis correspond to the SECOND input. Remember, columns are much more workable than rows when it comes to data manipulation.

# %% [markdown]
# ### 5.1: Practice with Pivot!
# Which state has the largest *proportion* of markets that sell seafood? Before you start, think about this question and come up with a hypothesis.
#
# Hypothesis: **answer here**
#
# Make a pivot table and add necessary adjustments to display the proportions. How do you get the proportions using your given data?

# %% [markdown]
# What Market Location will most often accept credit cards?

# %% [markdown]
# You may have heard of the Corn Belt, which are several states in the central northern US that are the country's largest producers of grains like corn and soybeans. Does this correlate well to the farmers_markets table? How can you tell? If it doesn't, suggest 2 reasons why that may be the case.

# %% [markdown]
# ### 5.2: Pivot 2: More Pivot
# The .pivot method has a cool quirk where, by adding a third header and a function as an argument, you can (much like .group) get the average/min/max/whatever for each of the delineated groups in the pivot table. This may be better to explain with a demonstration.

# %%
imdb.pivot('Rating', 'Decade', 'Votes', np.average)

# %% [markdown]
# This is the exact same as the example pivot table except, instead of listing the number of movies, it gives the average votes. Thus, looking at the 52419 in the first row, it indicates that, on average, the movies that were released in the 1920s AND scored a 8.2 had an average of 52419 votes.
#
# At the moment, I can't really think of a way to use this with the 4 tables we have at hand. However, it may be useful in future labs/exercises and in your final projects.

# %% [markdown]
# ## Conclusion
# And that's the end of Exercises 03! I admit, this was a beefy one. Please provide feedback and any avenues for improvement in the cell below.

# %% [markdown]
# Unfortunately, I didn't put any secret codes in this Exercise 03. (Gotta make all five points really worth your while!)
