# %% [markdown]
# # Review of Lab 02 <font color='blue'>Version 1.3</font>

# %% [markdown]
# Welcome to the Review Activity for Lab 02!

# %%
# don't touch this cell. Well, run it of course, but don't change anything inside it. Or else this whole thing could break. :<

import json
import random as _r
from IPython.display import HTML, display
import ipywidgets as widgets
from gofer.ok import check
from review_submit import *

CB_WIDGETS = {}

# %% [markdown]
# We have just recently buffed the Codebuilder's capacities!

# %% [markdown]
# A brand new feature is that you can save your work, even across different kernels!
#
# If you accidentally reran a codebuilder cell that had your work, your progress should still be preserved in that rerun.
#
# If you need to leave Jupyter but want to keep working later, run this cell below (**but remove the # at the start**) to save it. This will put your work in an external file.

# %%
# save_cb_state(CB_WIDGETS)

# %% [markdown]
# And when you come back (hi again!) just run this cell (**remove #**) to load your work back up.

# %%
# CB_WIDGETS = load_cb_state()

# %% [markdown]
# ## Multiple Choice!
# Lab 02 is a beefy one with lots of topics. This MC contains a summary of the most important.

# %%
questions(2, 0)

# %% [markdown]
# ## CodeBuilder!
# All of these will involve lists or arrays, as they play a huge role in all of your future datascience labs.
#
# If you ever need help, look to the MC questions above.

# %% [markdown]
# ### CodeBuilder 0
# Let's start off easy: Create a line of code that assigns a list to the variable `example_list`. The list should contain the following terms, in this order: 0, 7, 3, 5, 2. <br>Don't use any operators except assignment here.

# %%
state0 = codebuilder(0, CB_WIDGETS)

# %% [markdown]
# ### CodeBuilder 1
# This question involves the use of outside libraries. This is not really mentioned in lab 2 (oops), but you do use a function that comes from an outside library: `np.arange`. Here, the name of the function (`numpy`, but imported as `np`) is at the beginning of the function.
#
# Here, we'll use `average` (`mean` also works), which is also in the `numpy` library. Assume we have imported `numpy` as `np`, and get the average of the terms in the list `example_list`. Store the result in `list_avg`.

# %%
state1 = codebuilder(1, CB_WIDGETS)

# %% [markdown]
# ### CodeBuilder 2
# Use code to create an *array* of values that run from 0 to 10 inclusive, and store this in `numbers`.

# %%
state2 = codebuilder(2, CB_WIDGETS)

# %% [markdown]
# ### CodeBuilder 3
# Build a line of code that will find how many times the letter s appears in a `word`. For example, 'Mississippi' would give a count of 4. Store the result in `s_count`.
#
# Hint: Using `.split('s')` on `Mississippi` would get you a list with five strings in it (example below). Think of a way to get the number of terms in that list, and adjust it to output 4 instead.

# %%
# example:

'Mississippi'.split('s') # this outputs 5 segments, but the letter s only appears 4 times.

# %%
state3 = codebuilder(3, CB_WIDGETS)

# %% [markdown]
# ### CodeBuilder 4
# A long time ago, there was this curse called the Curse of Tippecanoe. If a US president's term began on a year that was a multiple of twenty after 1841 (e.g. 1841, 1861, 1881, and so forth), that president would die in office. It finally ended when Ronald Reagan (elected in 1981) did not die in office (though he did come close to dying once).
#
# How many presidents did the Curse kill? Store this in `dead_prezzes`.
#
# Hint: You'll need two functions for this; one to generate the years, and another to count them.

# %%
state4 = codebuilder(4, CB_WIDGETS)

# %% [markdown]
# ### CodeBuilder 5
# This builds on what you did for CodeBuilder 3. Suppose instead of a single word, you want to find the number of `s`'s in a whole list of `words`. Use list comprehension to get the counts, and store them all in `s_counts`. Use `x` to represent each term.
#
# Hint: The structure is fundamentally similar to that of CodeBuilder 3.

# %%
state5 = codebuilder(5, CB_WIDGETS)

# %% [markdown]
# ### CodeBuilder 6
# Challenge time! Suppose you have a massive string called `text`, and you want to see how many of each vowel there are. You have `vowels` defined as `['a', 'e', 'i', 'o', 'u', 'y']`, and you want to use List Comprehension to have Python calculate them all at once. Store the result in `vowel_counts`.
#
# Hint: recall how you integrated the code from CodeBuilder 3 into CodeBuilder 5. If you did it correctly, you should have replaced something in that code with `x`; here, you'll do the same thing, but replace a different part.

# %%
state6 = codebuilder(6, CB_WIDGETS)

# %% [markdown]
# ## End of Review 2!
# Hello again! If you've here, you've either done everything or you're quite mentally exhausted (and that's alright, because I admit this is quite a step-up from Labs 0 and 1). Don't worry, if you don't submit it we won't penalize you; however, if you have gone the extra distance, you can very well submit it and it will be logged just like your labs.
#
# We're only grading your CodeBuilders, which are each worth 3 pts. This begets a total score of 18 pts; doing the Challenge will get you an additional 3 pts, and finding the secret code (!) gets you another 2 pts. Thus, you can potentially get 23/18 pts.
#
# If you've found the secret code, feel free to enter it below. (Replace the question mark with your guess!)
#
# Hint: You'll need to find two things to get this, and then combine them in a new cell (follow the pattern!). The code will have a number in it.

# %% [markdown]
# ?

# %%
check('secret_code.py')

# %% [markdown]
# If you're having trouble, search throughout this page. I assure you it's there.

# %% [markdown]
# ## Submission (if you want)
# The table below shows a summary of all the codebuilders that you partook in. For some of these, there are multiple correct answers, so this is designed to get the correct answer closest to your work. That determines the number in the 'out of' column.

# %%
cb_summary(CB_WIDGETS)

# %%
submit_review(name, user, CB_WIDGETS, review_id='Review 2')
