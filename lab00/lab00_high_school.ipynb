# %% [markdown]
# # Welcome to Jupyter Notebooks! 🚀
#
# ### Your first steps in Python programming
#
# A **Jupyter notebook** is a place where you can write code, run it, and see the results — all in the same page. Think of it like a super-powered calculator that can also take notes!
#
# ---

# %%
# At the start of each lab, you'll see an import cell:
# this installs the necessary packages for the code to work. :>
# To run a cell, press Shift-Enter.

from lab00_init import *

# %%
# Please replace the ... below with your name. Do not delete the quotation marks.

name = '...'

# %% [markdown]
# ## Part 1 — Two Kinds of Cells
#
# Everything in a notebook lives in a **cell**. There are two types:
#
# - 📝 **Markdown cells** — for writing text (like this one!)
# - 💻 **Code cells** — for writing Python code
#
# **To run any cell:** click on it, then press **Shift + Enter** (hold Shift, press Enter).
#
# > **Try it:** Double-click on this text cell to see what's inside. Then press **Shift + Enter** to go back to normal.

# %% [markdown]
# ## Part 2 — Your First Code
#
# The cell below is a **code cell** (it has a grey background). Run it with **Shift + Enter**!

# %%
# Lines that start with # are called "comments" — Python ignores them.
# They are notes for YOU, the programmer.

print("Hello, World!")
print("I am running Python code!")

# %% [markdown]
# `print()` tells Python to display a message on screen.
#
# <div class="question-box">✏️ <b>Question 1:</b> Edit the code cell below to print your own name. Change the word <code>Your Name Here</code> to your actual name, then run it with Shift + Enter.</div>

# %%
print("Hello! My name is Your Name Here.")

# %% [markdown]
# ## Part 3 — Variables
#
# A **variable** is like a labeled box that stores a value. You create one using `=`.
#
# ```python
# age = 12          # stores the number 12 in a box called "age"
# name = "Alex"     # stores the text "Alex" in a box called "name"
# ```
#
# Once stored, you can use the variable anywhere in your code!

# %%
animal = "penguin"
number_of_legs = 2

print("My favorite animal is the", animal)
print("It has", number_of_legs, "legs")

# %% [markdown]
# <div class="question-box">✏️ <b>Question 2:</b> In the cell below, create a variable called <code>animal</code> and set it to YOUR favorite animal. Then create a variable called <code>legs</code> and set it to how many legs that animal has. Print a sentence using both variables.</div>

# %%
# Your code here!
animal = ...
legs = ...
print("My favorite animal is the", animal, "and it has", legs, "legs!")

# %%
# This is a check cell! It grades your code in the earlier question. The more checks you pass, the more points you earn.
check("tests/q0.py")

# %% [markdown]
# ## Part 4 — Python as a Calculator
#
# Python can do math! Here are the symbols to use:
#
# | Symbol | Meaning | Example |
# |--------|---------|--------|
# | `+` | add | `3 + 4` → 7 |
# | `-` | subtract | `10 - 3` → 7 |
# | `*` | multiply | `3 * 4` → 12 |
# | `/` | divide | `20 / 4` → 5.0 |
# | `**` | power | `2 ** 3` → 8 |

# %%
# Python can do math!
print(5 + 3)
print(10 - 4)
print(3 * 7)
print(2 ** 4)   # 2 to the power of 4

# %% [markdown]
# <div class="question-box">✏️ <b>Question 3:</b> A pizza has 8 slices and you have 3 friends (plus yourself = 4 people). Use Python to calculate how many slices each person gets. Store the number of slices in a variable called <code>slices</code> and the number of people in <code>people</code>, then print the result.</div>

# %%
slices = ...
people = ...

# don't change these last two lines!
each_person_gets = slices / people
print("Each person gets", each_person_gets, "slices")

# %%
check('tests/q1.py')

# %% [markdown]
# ## Part 5 — Making Mistakes is OK! 🐛
#
# Everyone makes errors in code — even professional programmers! When you make a mistake, Python gives you an **error message** to help you find and fix it.
#
# Run the cell below and look at the error message. Can you see what's wrong?

# %%
# There is a bug in this code! Run it, read the error, then fix it.
print("Python is awesome!"

# %% [markdown]
# > **What was missing?** The closing `)` parenthesis! Fix it in the cell above and run it again.
#
# Error messages are your **friends** — they tell you exactly where to look. The trick is to read them carefully.

# %% [markdown]
# ## 🎉 Great Work!
#
# ### What you learned today:
# - The difference between **Markdown cells** and **Code cells**
# - How to use `print()` to display messages
# - How to create **variables** to store text and numbers
# - How to use Python as a **calculator**
# - How to read **error messages** and fix bugs
#
# ---
#
# <div class="question-box">✏️ <b>Reflection:</b> Double-click on the cell below and answer these questions in your own words:
#
# 1. What is a variable?
# 2. What was the hardest part of this notebook?
# 3. What was the most fun part?
# </div>

# %% [markdown]
# Double-click this text, and put your answers here!

# %%
check('tests/q2_open_ended.py')

# %% [markdown]
# ## ✅ Final Check & Submit
# At the end of every lab, we'll have a section for you to quickly check that all problems are completed. We will mainly be collecting your lab results through this automatic grader, and any open-ended responses will be sent to a spreadsheet. This is done via the **Submit Lab** button that appears when you run the second cell below.

# %%
for x in ["0", "1","2_open_ended"]:
    print(f"Q{x}:", end="  ")
    display(check(f"tests/q{x}.py"))

# %%
from lab_submit import submit_lab
questions = ["0", "1","2_open_ended"]
correct = sum(1 for q in questions if check(f'tests/q{q}.py').grade == 1.0)
submit_lab(name, user, correct, questions, 'Lab 00 HS')
