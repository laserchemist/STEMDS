# %% [markdown]
# # Review of Lab 0 <font color='blue'>Version 1.0</font>

# %%
# don't touch this cell. Well, run it of course, but don't change anything inside it. Or else this whole thing could break. :<

import json
import random as _r
from IPython.display import HTML, display
import os
from jupyterquiz import display_quiz

def codebuilder(level):
    _uid = _r.randint(100000, 999999)
    with open("CodeBuilder.html", "r", encoding="utf-8") as f:
        html = f.read()

    html = html.replace("__LEVEL__", 'level'+str(level)).replace("%%UID%%", str(_uid))

    display(HTML(html))


def questions(lab, level):
    with open("Q" + str(lab) + '_' + str(level) + ".json", "r") as file:
        questions=json.load(file)    
    display_quiz(questions)

# %% [markdown]
# # Introduction
# Welcome to the CodeBuilding Activities! These are newly-designed interactive questions that are intended to help you review the content from labs and integrate what you learn into how you approach coding.
#
# Each activity consists of either a block interface or a couple multiple choice questions. You are welcome (encouraged, even) to insert cells and play around with the code on your own.

# %% [markdown]
# # CodeBuilding Exercises
# These take the form of small interfaces that you drag blocks towards. Use this first problem as an example; drag blocks to spell out `print(x)`.

# %%
codebuilder(0)

# %% [markdown]
# ## CodeBuilder 1:
# In this CodeBuilding activity, suppose that the following code cells have been already run.
#
# `y = 2`
#
# `z = 3`
#
# Using the blocks you have available, construct a line of code that will assign `x` to `5`. (there are 4 solutions; try to find all of them!)

# %%
codebuilder(1)

# %% [markdown]
# ## CodeBuilder 2:

# %% [markdown]
# Use these following blocks to construct a line of code that will print out `Hello World!`, given that the following lines of code were run earlier.
#
# `x = '!'`
#
# `y = 'World'`
#
# `z = 'Hello'`
#
# Hint: adding a comma between two arguments automatically adds a space, but having a plus sign between two strings does not add a space.

# %%
codebuilder(2)

# %% [markdown]
# ## CodeBuilder 3
# The grocery store is 0.75 miles away from your house. Suppose it takes you 20 minutes to go there, 30 minutes to shop, and 50 minutes to walk back (with all the groceries in tow). Construct code using only variables that will calculate how much time was spent on this journey. The following lines have already been run:
#
# `distance = 0.75`
#
# `time_to = 20`
#
# `time_shop = 30`
#
# `time_back = 50`
#
# Store the result in `time_total`.

# %%
codebuilder(3)

# %% [markdown]
# ## CodeBuilder 4
# Continuing onwards with the same scenario, type in code to find the average speed, given the following:
# $$average\; speed = \frac{total\; distance}{total\; time}$$
#
# You also know that inside the store you walked about 0.3 miles, and this value is stored inside `dist_shopping`.
#
# Hints:
# * Use the variable you made in CodeBuilder 3!
# * Remember PEMDAS. What additional syntax should you incorporate to have the code calculate properly?
# * What's your total distance across all of these trips? This consists of two variables you should add together.
# * Store the result in `average_speed`.
#
# (Assume the code that was run before codebuilder 3 was also run before codebuilder 4.)

# %%
codebuilder(4)

# %% [markdown]
# # Multiple-Choice Questions

# %% [markdown]
# ## Part 1: Variables and Assignment
# These pertain to the material introduced in Questions 1a, 1b, and 3.

# %%
questions(0, 0)

# %% [markdown]
# ## The Print Function
# These pertain to the material introduced in Questions 1a, 1b, and 2.

# %%
questions(0, 1)

# %% [markdown]
# ## Technics
# This is for material covered in the later sections of Lab 0, as well as other information that will be useful to you while you do data science.

# %%
questions(0,2)

# %% [markdown]
# # The End? Or perhaps the beginning?
# This ends the Review of Lab 0. These are a new addition for the STEM-UP 2026; feel free to add any words of feedback below!
# * Did this help you internalize the material better?
# * Are there spots in the Lab we missed?
# * Is the length of this Review adequate?
