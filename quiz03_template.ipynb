# %% [markdown]
# # 📝 Quiz 03 — Tables & Probability
#
# <div style="background:#fff3cd;border-left:6px solid #ffc107;padding:12px 16px;border-radius:6px;margin:10px 0;">
# This is a <b>graded quiz</b>. Your score will be recorded automatically when you
# click <b>Submit Quiz</b> at the bottom.<br><br>
# Rules: open notes, closed internet searches. Work independently.
# </div>

# %% [markdown]
# ### Setup — run this first

# %%
from lab03_init import *   # loads display_quiz, json, apply_style, user, etc.

# ── score tracking ──────────────────────────────────────────────────────────
# jupyterquiz does not expose a score programmatically, so we track it here.
# Update quiz_score below after completing the quiz and reviewing your answers.
quiz_score = 0    # ← YOU fill this in before submitting
quiz_total = 10   # total number of questions in the quiz
name = "..."      # ← YOUR name
print(f"Quiz ready — {quiz_total} questions | user: {user}")

# %% [markdown]
# ## Questions

# %%
# Run this cell to display the quiz.
# Answer every question, then update quiz_score above before submitting.
with open("questions_quiz03.json", "r") as f:
    display_quiz(json.load(f))

# %% [markdown]
# <div style="background:#fff3cd;border-left:6px solid #ffc107;padding:12px 16px;border-radius:6px;margin:10px 0;">
# ⬆️ Answer all questions above, then fill in <code>quiz_score</code> in the
# Setup cell with the number you got correct, and run <b>Submit Quiz</b> below.
# </div>

# %%
from lab_submit_canvas import submit_quiz

# quiz_score is set in the Setup cell above — update it before clicking Submit!
submit_quiz(name, user, quiz_score, quiz_total, quiz_id="Quiz03")
