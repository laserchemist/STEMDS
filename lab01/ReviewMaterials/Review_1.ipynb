# %% [markdown]
# # Review of Lab 01

# %% [markdown]
# Welcome to the Review Activity for Lab 01!

# %%
# don't touch this cell. Well, run it of course, but don't change anything inside it. Or else this whole thing could break. :<

import json
import random as _r
from IPython.display import HTML, display
import os
from jupyterquiz import display_quiz

def codebuilder(level):
    _uid = _r.randint(100000, 999999)
    with open("CodeBuilder.html", "r", encoding="utf-8") as f:
        html = f.read()

    html = html.replace("__LEVEL__", 'level'+str(level)).replace("%%UID%%", str(_uid))

    display(HTML(html))


def questions(lab, level):
    with open("Q" + str(lab) + '_' + str(level) + ".json", "r") as file:
        questions=json.load(file)    
    display_quiz(questions)

# %% [markdown]
# ## Data Types and Functions
# Since the Lab itself shares a lot in common with Lab 0, There is only one set of MC questions for it.

# %%
questions(1, 0)

# %% [markdown]
# ## Crossing the Rubicon
# I'm not putting any CodeBuilder stuff here because (1) the main problems here are PEMDAS and other math concepts, and (2) you will do plenty of that in the labs and the Exercise 1, and (3) coding in the grader for those math problems is really tedious.
#
# Thus ends the Review 1! I hope you've been enjoying coding so far. Of course, feel free to leave feedback! Is this Review sufficiently reflective of the Lab? Was there stuff we missed?
#
# **<Replace this with your response!>**

# %% [markdown]
# Also, I really do hope you've been keeping up logging entries into your library. Come Labs 2 and 3 will be the bulk of the functions/methods/other fun stuff you'll be learning. If you haven't gotten used to entering things in the library, you'll find this upcoming deluge of information quite overwhelming.
#
# I can think of 12 things (8 operations, 2 functions, 2 methods) that are found just in Labs 0 and 1, and Exercise 1. Of course, you're more than welcome to have more than 12 entries in the library.
