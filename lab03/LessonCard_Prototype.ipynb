# %% [markdown]
# # Prototype of the Lesson Cards
#
# These are designed to be easily callable from any lab, such that if they are stuck on what to do for a later lab and/or even their final project, they can simply use these cards without having to flip back through the earlier labs.
#
# Since we have so much freedom as to what to put on each card, and how to arrange it, this has the potential to make the labs, particularly 2 and 3, much simpler and shorter.

# %%
from lessoncards import *

# %%
from lessons.test import *

# %%
print(REFERENCE_LIBRARY.keys())
# Out:
# dict_keys(['table_intro', 'table_creation', 'table_method', 'table_column', 'table_sort'])

# %%
UNLOCKED_LESSONS
# Out:
# set()

# %%
table_intro.show()
# Out:
#
#         <div id="lesson_2f0daa0490df4ab59643a8a4556457e0" class="lesson-wrapper">
#
#
#             <div class="lesson-title">
#
#                 Introduction to Tables
#
#             </div>
#
#
#             <div class="lesson-main">
#
#
#                 <button class="nav-button left"
#
#                     onclick="prev_lesson_2f0daa0490df4ab59643a8a4556457e0()">
#
#                     ◀
#
#                 </button>
#
#
#
#                 <div class="lesson-card"
#
#                     id="lesson_2f0daa0490df4ab59643a8a4556457e0_content">
#
#                 </div>
#
#
#
#                 <button class="nav-button right"
#
#                     onclick="next_lesson_2f0daa0490df4ab59643a8a4556457e0()">
#
#                     ▶
#
#                 </button>
#
#
#             </div>
#
#
#
#             <div class="lesson-progress"
#
#                 id="lesson_2f0daa0490df4ab59643a8a4556457e0_counter">
#
#             </div>
#
#
#
#         </div>
#
#
#
#         <style>
#
#         .note-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f5f5f5;
#
#         }
#
#
#
#         .note-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .note-content {
#
#             line-height:1.5;
#
#         }
#
#         .warning-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #999999;
#
#             background:#fafafa;
#
#         }
#
#
#
#         .warning-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .warning-content {
#
#             line-height:1.5;
#
#         }
#
#         .example-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f8f8f8;
#
#         }
#
#
#
#         .example-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .example-content {
#
#             line-height:1.5;
#
#         }
#
#         .image-wrapper {
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#             text-align:center;
#
#         }
#
#         .card-list {
#
#             margin-top: 15px;
#
#             margin-bottom: 15px;
#
#             line-height: 1.6;
#
#         }
#
#
#
#         .card-image {
#
#             max-width:100%;
#
#             border-radius:10px;
#
#         }
#
#         .card-row {
#
#             display:flex;
#
#             align-items:center;
#
#             gap:25px;
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .row-item {
#
#             min-width:0;
#
#         }
#
#         .card-column {
#
#             display:flex;
#
#             flex-direction:column;
#
#             gap:15px;
#
#         }
#
#
#         .lesson-wrapper {
#
#             width:900px;
#             margin:auto;
#
#             font-family:
#             Arial, sans-serif;
#
#         }
#
#
#
#         .lesson-title {
#
#             font-size:28px;
#             font-weight:bold;
#
#             text-align:center;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .lesson-main {
#
#             display:flex;
#
#             align-items:center;
#
#             justify-content:center;
#
#             gap:25px;
#
#         }
#
#
#
#         .lesson-card {
#
#             width:650px;
#
#             min-height:300px;
#
#             border:
#             1px solid #cccccc;
#
#             border-radius:14px;
#
#             padding:30px;
#
#             box-shadow:
#             0px 3px 8px rgba(0,0,0,0.15);
#
#         }
#
#
#
#         .nav-button {
#
#             width:45px;
#
#             height:70px;
#
#             border-radius:10px;
#
#             border:
#             1px solid #aaaaaa;
#
#             background:white;
#
#             font-size:25px;
#
#             cursor:pointer;
#
#         }
#
#
#
#         .nav-button:hover {
#
#             background:#eeeeee;
#
#         }
#
#
#
#         .lesson-progress {
#
#             text-align:center;
#
#             margin-top:20px;
#
#             color:#666666;
#
#             font-size:15px;
#
#         }
#
#         .code-wrapper {
#
#             position: relative;
#
#             margin-top: 20px;
#
#             margin-bottom: 20px;
#
#         }
#
#
#         .copy-button {
#
#             position: absolute;
#
#             top: 8px;
#
#             right: 8px;
#
#             border: none;
#
#             background: transparent;
#
#             cursor: pointer;
#
#             font-size: 18px;
#
#             opacity: 0.6;
#
#         }
#
#         .copy-button:hover {
#
#             opacity: 1;
#
#         }
#
#
#
#         .code-block {
#
#             background: #f2f2f2;
#
#             border: 1px solid #dddddd;
#
#             border-radius: 8px;
#
#             padding: 18px;
#
#             overflow-x: auto;
#
#             font-family: "Courier New", monospace;
#
#             font-size: 14px;
#
#         }
#
#
#         </style>
#
#
#
#         <script type="text/javascript">
#
#         function copyCode(id){
#
#             navigator.clipboard.writeText(
#                 document
#                 .getElementById(id)
#                 .innerText
#                 .trim()
#             );
#
#         }
#
#         let cards_lesson_2f0daa0490df4ab59643a8a4556457e0 = ["\n\n        <div class=\"card-row\">\n\n            \n\n            <div class=\"row-item\"\n            style=\"flex:1;\">\n\n                \n        <div class=\"image-wrapper\">\n\n            <img\n            src=\"data:image/png;base64,...\"\n            style=\"width:250px;\"\n            class=\"card-image\">\n\n        </div>\n        \n\n            </div>\n\n            \n\n            <div class=\"row-item\"\n            style=\"flex:1;\">\n\n                \n\n        <div class=\"card-column\">\n\n            \n        <h2 class=\"card-heading\">\n            What is a Table?\n        </h2>\n        \n        <div class=\"card-text\">\n            A table is a way of storing and organizing data, much like lists, arrays, and strings. It consists of a grid, much like those you would find and make in Excel.\n        </div>\n        \n\n        <div class=\"note-box\">\n\n            <div class=\"note-title\">\n\n                \ud83d\udca1 Note\n\n            </div>\n\n\n            <div class=\"note-content\">\n\n                The tables we will work with in this course are from the <strong>datascience</strong> module, so if the Tables aren&#x27;t showing, try running the following code.\n\n            </div>\n\n        </div>\n\n        \n\n        <div class=\"code-wrapper\">\n\n            <button\n                class=\"copy-button\"\n                onclick=\"copyCode('code_142729c1bde740758a3891dd26c93ede')\">\n        \n                \ud83d\udccb\n        \n            </button>\n        \n            <pre id=\"code_142729c1bde740758a3891dd26c93ede\" class=\"code-block\">from datascience import *</pre>\n        \n        </div>\n\n        \n\n

# %%
table_creation.show()
# Out:
#
#         <div id="lesson_45c67c54b01c496fb239a1804873e09b" class="lesson-wrapper">
#
#
#             <div class="lesson-title">
#
#                 Making Tables
#
#             </div>
#
#
#             <div class="lesson-main">
#
#
#                 <button class="nav-button left"
#
#                     onclick="prev_lesson_45c67c54b01c496fb239a1804873e09b()">
#
#                     ◀
#
#                 </button>
#
#
#
#                 <div class="lesson-card"
#
#                     id="lesson_45c67c54b01c496fb239a1804873e09b_content">
#
#                 </div>
#
#
#
#                 <button class="nav-button right"
#
#                     onclick="next_lesson_45c67c54b01c496fb239a1804873e09b()">
#
#                     ▶
#
#                 </button>
#
#
#             </div>
#
#
#
#             <div class="lesson-progress"
#
#                 id="lesson_45c67c54b01c496fb239a1804873e09b_counter">
#
#             </div>
#
#
#
#         </div>
#
#
#
#         <style>
#
#         .note-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f5f5f5;
#
#         }
#
#
#
#         .note-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .note-content {
#
#             line-height:1.5;
#
#         }
#
#         .warning-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #999999;
#
#             background:#fafafa;
#
#         }
#
#
#
#         .warning-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .warning-content {
#
#             line-height:1.5;
#
#         }
#
#         .example-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f8f8f8;
#
#         }
#
#
#
#         .example-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .example-content {
#
#             line-height:1.5;
#
#         }
#
#         .image-wrapper {
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#             text-align:center;
#
#         }
#
#         .card-list {
#
#             margin-top: 15px;
#
#             margin-bottom: 15px;
#
#             line-height: 1.6;
#
#         }
#
#
#
#         .card-image {
#
#             max-width:100%;
#
#             border-radius:10px;
#
#         }
#
#         .card-row {
#
#             display:flex;
#
#             align-items:center;
#
#             gap:25px;
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .row-item {
#
#             min-width:0;
#
#         }
#
#         .card-column {
#
#             display:flex;
#
#             flex-direction:column;
#
#             gap:15px;
#
#         }
#
#
#         .lesson-wrapper {
#
#             width:900px;
#             margin:auto;
#
#             font-family:
#             Arial, sans-serif;
#
#         }
#
#
#
#         .lesson-title {
#
#             font-size:28px;
#             font-weight:bold;
#
#             text-align:center;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .lesson-main {
#
#             display:flex;
#
#             align-items:center;
#
#             justify-content:center;
#
#             gap:25px;
#
#         }
#
#
#
#         .lesson-card {
#
#             width:650px;
#
#             min-height:300px;
#
#             border:
#             1px solid #cccccc;
#
#             border-radius:14px;
#
#             padding:30px;
#
#             box-shadow:
#             0px 3px 8px rgba(0,0,0,0.15);
#
#         }
#
#
#
#         .nav-button {
#
#             width:45px;
#
#             height:70px;
#
#             border-radius:10px;
#
#             border:
#             1px solid #aaaaaa;
#
#             background:white;
#
#             font-size:25px;
#
#             cursor:pointer;
#
#         }
#
#
#
#         .nav-button:hover {
#
#             background:#eeeeee;
#
#         }
#
#
#
#         .lesson-progress {
#
#             text-align:center;
#
#             margin-top:20px;
#
#             color:#666666;
#
#             font-size:15px;
#
#         }
#
#         .code-wrapper {
#
#             position: relative;
#
#             margin-top: 20px;
#
#             margin-bottom: 20px;
#
#         }
#
#
#         .copy-button {
#
#             position: absolute;
#
#             top: 8px;
#
#             right: 8px;
#
#             border: none;
#
#             background: transparent;
#
#             cursor: pointer;
#
#             font-size: 18px;
#
#             opacity: 0.6;
#
#         }
#
#         .copy-button:hover {
#
#             opacity: 1;
#
#         }
#
#
#
#         .code-block {
#
#             background: #f2f2f2;
#
#             border: 1px solid #dddddd;
#
#             border-radius: 8px;
#
#             padding: 18px;
#
#             overflow-x: auto;
#
#             font-family: "Courier New", monospace;
#
#             font-size: 14px;
#
#         }
#
#
#         </style>
#
#
#
#         <script type="text/javascript">
#
#         function copyCode(id){
#
#             navigator.clipboard.writeText(
#                 document
#                 .getElementById(id)
#                 .innerText
#                 .trim()
#             );
#
#         }
#
#         let cards_lesson_45c67c54b01c496fb239a1804873e09b = ["\n\n        <div class=\"card-row\">\n\n            \n\n            <div class=\"row-item\"\n            style=\"\">\n\n                \n\n        <div class=\"card-column\">\n\n            \n        <h2 class=\"card-heading\">\n            Making Tables Manually\n        </h2>\n        \n        <div class=\"card-text\">\n            If we have several lists or arrays, we can combine them into a table, where each list/array becomes one column. This is done via the code to the right.\n        </div>\n        \n        <div class=\"card-text\">\n            <code>Table().with_columns</code> creates a new table. By storing it in a variable (such as <code>newTable</code>), we can access that table later by calling the variable.\n        </div>\n        \n\n        <div class=\"warning-box\">\n\n            <div class=\"warning-title\">\n\n                \u26a0 Warning\n\n            </div>\n\n\n            <div class=\"warning-content\">\n\n                Each list/array that you put in a table <strong>must</strong> have the same number of terms.\n\n            </div>\n\n        </div>\n\n        \n\n        </div>\n\n        \n\n            </div>\n\n            \n\n            <div class=\"row-item\"\n            style=\"\">\n\n                \n\n        <div class=\"card-column\">\n\n            \n\n        <div class=\"note-box\">\n\n            <div class=\"note-title\">\n\n                \ud83d\udca1 Note\n\n            </div>\n\n\n            <div class=\"note-content\">\n\n                The code below will generate a table with <strong>two</strong> columns, one for each array. If you&#x27;d like to add more than two, simply continue the pattern of alternating the header

# %%
table_method.show()
# Out:
#
#         <div id="lesson_7746e73ac5164df0b6d8ee63342a1430" class="lesson-wrapper">
#
#
#             <div class="lesson-title">
#
#                 Table Methods
#
#             </div>
#
#
#             <div class="lesson-main">
#
#
#                 <button class="nav-button left"
#
#                     onclick="prev_lesson_7746e73ac5164df0b6d8ee63342a1430()">
#
#                     ◀
#
#                 </button>
#
#
#
#                 <div class="lesson-card"
#
#                     id="lesson_7746e73ac5164df0b6d8ee63342a1430_content">
#
#                 </div>
#
#
#
#                 <button class="nav-button right"
#
#                     onclick="next_lesson_7746e73ac5164df0b6d8ee63342a1430()">
#
#                     ▶
#
#                 </button>
#
#
#             </div>
#
#
#
#             <div class="lesson-progress"
#
#                 id="lesson_7746e73ac5164df0b6d8ee63342a1430_counter">
#
#             </div>
#
#
#
#         </div>
#
#
#
#         <style>
#
#         .note-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f5f5f5;
#
#         }
#
#
#
#         .note-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .note-content {
#
#             line-height:1.5;
#
#         }
#
#         .warning-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #999999;
#
#             background:#fafafa;
#
#         }
#
#
#
#         .warning-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .warning-content {
#
#             line-height:1.5;
#
#         }
#
#         .example-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f8f8f8;
#
#         }
#
#
#
#         .example-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .example-content {
#
#             line-height:1.5;
#
#         }
#
#         .image-wrapper {
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#             text-align:center;
#
#         }
#
#         .card-list {
#
#             margin-top: 15px;
#
#             margin-bottom: 15px;
#
#             line-height: 1.6;
#
#         }
#
#
#
#         .card-image {
#
#             max-width:100%;
#
#             border-radius:10px;
#
#         }
#
#         .card-row {
#
#             display:flex;
#
#             align-items:center;
#
#             gap:25px;
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .row-item {
#
#             min-width:0;
#
#         }
#
#         .card-column {
#
#             display:flex;
#
#             flex-direction:column;
#
#             gap:15px;
#
#         }
#
#
#         .lesson-wrapper {
#
#             width:900px;
#             margin:auto;
#
#             font-family:
#             Arial, sans-serif;
#
#         }
#
#
#
#         .lesson-title {
#
#             font-size:28px;
#             font-weight:bold;
#
#             text-align:center;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .lesson-main {
#
#             display:flex;
#
#             align-items:center;
#
#             justify-content:center;
#
#             gap:25px;
#
#         }
#
#
#
#         .lesson-card {
#
#             width:650px;
#
#             min-height:300px;
#
#             border:
#             1px solid #cccccc;
#
#             border-radius:14px;
#
#             padding:30px;
#
#             box-shadow:
#             0px 3px 8px rgba(0,0,0,0.15);
#
#         }
#
#
#
#         .nav-button {
#
#             width:45px;
#
#             height:70px;
#
#             border-radius:10px;
#
#             border:
#             1px solid #aaaaaa;
#
#             background:white;
#
#             font-size:25px;
#
#             cursor:pointer;
#
#         }
#
#
#
#         .nav-button:hover {
#
#             background:#eeeeee;
#
#         }
#
#
#
#         .lesson-progress {
#
#             text-align:center;
#
#             margin-top:20px;
#
#             color:#666666;
#
#             font-size:15px;
#
#         }
#
#         .code-wrapper {
#
#             position: relative;
#
#             margin-top: 20px;
#
#             margin-bottom: 20px;
#
#         }
#
#
#         .copy-button {
#
#             position: absolute;
#
#             top: 8px;
#
#             right: 8px;
#
#             border: none;
#
#             background: transparent;
#
#             cursor: pointer;
#
#             font-size: 18px;
#
#             opacity: 0.6;
#
#         }
#
#         .copy-button:hover {
#
#             opacity: 1;
#
#         }
#
#
#
#         .code-block {
#
#             background: #f2f2f2;
#
#             border: 1px solid #dddddd;
#
#             border-radius: 8px;
#
#             padding: 18px;
#
#             overflow-x: auto;
#
#             font-family: "Courier New", monospace;
#
#             font-size: 14px;
#
#         }
#
#
#         </style>
#
#
#
#         <script type="text/javascript">
#
#         function copyCode(id){
#
#             navigator.clipboard.writeText(
#                 document
#                 .getElementById(id)
#                 .innerText
#                 .trim()
#             );
#
#         }
#
#         let cards_lesson_7746e73ac5164df0b6d8ee63342a1430 = ["\n        <h2 class=\"card-heading\">\n            The Basic Structure of Table methods\n        </h2>\n        \n        <div class=\"card-text\">\n            Beyond creating/loading a new table, all subsequent table methods will be some alteration/transformation to an existing table. So, all of these methods will have the same general structure. This consists of three parts.\n        </div>\n        \n        <ul class=\"card-list\">\n            <li>The existing table that you are altering (in green)</li><li>The name of the method (blue)</li><li>Any arguments that it needs (red)</li>\n        </ul>\n        \n        <div class=\"card-text\">\n            This sample below showsan example of <code>.column</code>, which you will be formally introduced to later.\n        </div>\n        \n\n        <div class=\"image-wrapper\">\n\n            <img\n            src=\"data:image/png;base64,...\"\n            style=\"\"\n            class=\"card-image\">\n\n        </div>\n\n        ", "\n        <h2 class=\"card-heading\">\n            Perserving Modifications to Tables\n        </h2>\n        \n        <div class=\"card-text\">\n            While we often say that these methods <em>modify</em> the table, that is not strictly true. Instead, these methods <strong>create a version of the table</strong> with these modifications, but the actual table is not changed.\n        </div>\n        \n        <div class=\"card-text\">\n            You need to set a variable equal to that code in order to store whatever changes you make.\n        </div>\n        \n\n        <div class=\"card-row\">\n\n            \n\n            <div class=\"row-item\"\n            style=\"flex:1;\">\n\n

# %%
table_sort.show()
# Out:
#
#         <div id="lesson_ff13a009e9ab494a9aca114af7256b3c" class="lesson-wrapper">
#
#
#             <div class="lesson-title">
#
#                 Sorting Tables
#
#             </div>
#
#
#             <div class="lesson-main">
#
#
#                 <button class="nav-button left"
#
#                     onclick="prev_lesson_ff13a009e9ab494a9aca114af7256b3c()">
#
#                     ◀
#
#                 </button>
#
#
#
#                 <div class="lesson-card"
#
#                     id="lesson_ff13a009e9ab494a9aca114af7256b3c_content">
#
#                 </div>
#
#
#
#                 <button class="nav-button right"
#
#                     onclick="next_lesson_ff13a009e9ab494a9aca114af7256b3c()">
#
#                     ▶
#
#                 </button>
#
#
#             </div>
#
#
#
#             <div class="lesson-progress"
#
#                 id="lesson_ff13a009e9ab494a9aca114af7256b3c_counter">
#
#             </div>
#
#
#
#         </div>
#
#
#
#         <style>
#
#         .note-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f5f5f5;
#
#         }
#
#
#
#         .note-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .note-content {
#
#             line-height:1.5;
#
#         }
#
#         .warning-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #999999;
#
#             background:#fafafa;
#
#         }
#
#
#
#         .warning-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .warning-content {
#
#             line-height:1.5;
#
#         }
#
#         .example-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f8f8f8;
#
#         }
#
#
#
#         .example-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .example-content {
#
#             line-height:1.5;
#
#         }
#
#         .image-wrapper {
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#             text-align:center;
#
#         }
#
#         .card-list {
#
#             margin-top: 15px;
#
#             margin-bottom: 15px;
#
#             line-height: 1.6;
#
#         }
#
#
#
#         .card-image {
#
#             max-width:100%;
#
#             border-radius:10px;
#
#         }
#
#         .card-row {
#
#             display:flex;
#
#             align-items:center;
#
#             gap:25px;
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .row-item {
#
#             min-width:0;
#
#         }
#
#         .card-column {
#
#             display:flex;
#
#             flex-direction:column;
#
#             gap:15px;
#
#         }
#
#
#         .lesson-wrapper {
#
#             width:900px;
#             margin:auto;
#
#             font-family:
#             Arial, sans-serif;
#
#         }
#
#
#
#         .lesson-title {
#
#             font-size:28px;
#             font-weight:bold;
#
#             text-align:center;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .lesson-main {
#
#             display:flex;
#
#             align-items:center;
#
#             justify-content:center;
#
#             gap:25px;
#
#         }
#
#
#
#         .lesson-card {
#
#             width:650px;
#
#             min-height:300px;
#
#             border:
#             1px solid #cccccc;
#
#             border-radius:14px;
#
#             padding:30px;
#
#             box-shadow:
#             0px 3px 8px rgba(0,0,0,0.15);
#
#         }
#
#
#
#         .nav-button {
#
#             width:45px;
#
#             height:70px;
#
#             border-radius:10px;
#
#             border:
#             1px solid #aaaaaa;
#
#             background:white;
#
#             font-size:25px;
#
#             cursor:pointer;
#
#         }
#
#
#
#         .nav-button:hover {
#
#             background:#eeeeee;
#
#         }
#
#
#
#         .lesson-progress {
#
#             text-align:center;
#
#             margin-top:20px;
#
#             color:#666666;
#
#             font-size:15px;
#
#         }
#
#         .code-wrapper {
#
#             position: relative;
#
#             margin-top: 20px;
#
#             margin-bottom: 20px;
#
#         }
#
#
#         .copy-button {
#
#             position: absolute;
#
#             top: 8px;
#
#             right: 8px;
#
#             border: none;
#
#             background: transparent;
#
#             cursor: pointer;
#
#             font-size: 18px;
#
#             opacity: 0.6;
#
#         }
#
#         .copy-button:hover {
#
#             opacity: 1;
#
#         }
#
#
#
#         .code-block {
#
#             background: #f2f2f2;
#
#             border: 1px solid #dddddd;
#
#             border-radius: 8px;
#
#             padding: 18px;
#
#             overflow-x: auto;
#
#             font-family: "Courier New", monospace;
#
#             font-size: 14px;
#
#         }
#
#
#         </style>
#
#
#
#         <script type="text/javascript">
#
#         function copyCode(id){
#
#             navigator.clipboard.writeText(
#                 document
#                 .getElementById(id)
#                 .innerText
#                 .trim()
#             );
#
#         }
#
#         let cards_lesson_ff13a009e9ab494a9aca114af7256b3c = ["\n        <h2 class=\"card-heading\">\n            How to Sort a Table\n        </h2>\n        \n        <div class=\"card-text\">\n            Remember that almost all methods, including sorting, will <strong>not</strong> alter what is in a table row. So, when we refer to &#x27;sorting a table&#x27;, it will almost always mean sorting the <strong>rows</strong>.\n        </div>\n        \n\n        <div class=\"note-box\">\n\n            <div class=\"note-title\">\n\n                \ud83d\udca1 Note\n\n            </div>\n\n\n            <div class=\"note-content\">\n\n                This form sorts from <strong>smallest</strong> to <strong>largest</strong> (or, if the column is made of strings, from <strong>a</strong> to <strong>z</strong>). That means he smallest-valued rows are at the top.\n\n            </div>\n\n        </div>\n\n        \n\n        <div class=\"code-wrapper\">\n\n            <button\n                class=\"copy-button\"\n                onclick=\"copyCode('code_84612440ff1e438abe02bac46bf57f2a')\">\n        \n                \ud83d\udccb\n        \n            </button>\n        \n            <pre id=\"code_84612440ff1e438abe02bac46bf57f2a\" class=\"code-block\">table.sort(&#x27;header&#x27;)</pre>\n        \n        </div>\n\n        ", "\n\n        <div class=\"card-column\">\n\n            \n        <h2 class=\"card-heading\">\n            How to Sort in the Opposite Direction\n        </h2>\n        \n        <div class=\"card-text\">\n            This is remarkably similar to the previous form; all you need to do is add another argument.\n        </div>\n        \n\n        <div class=\"code-wrapper\">\n\n            <button\n                class=\"c

# %%
table_column.show()
# Out:
#
#         <div id="lesson_c1d911d17d1b40f697534ed28776c5f5" class="lesson-wrapper">
#
#
#             <div class="lesson-title">
#
#                 Extracting Information from Tables
#
#             </div>
#
#
#             <div class="lesson-main">
#
#
#                 <button class="nav-button left"
#
#                     onclick="prev_lesson_c1d911d17d1b40f697534ed28776c5f5()">
#
#                     ◀
#
#                 </button>
#
#
#
#                 <div class="lesson-card"
#
#                     id="lesson_c1d911d17d1b40f697534ed28776c5f5_content">
#
#                 </div>
#
#
#
#                 <button class="nav-button right"
#
#                     onclick="next_lesson_c1d911d17d1b40f697534ed28776c5f5()">
#
#                     ▶
#
#                 </button>
#
#
#             </div>
#
#
#
#             <div class="lesson-progress"
#
#                 id="lesson_c1d911d17d1b40f697534ed28776c5f5_counter">
#
#             </div>
#
#
#
#         </div>
#
#
#
#         <style>
#
#         .note-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f5f5f5;
#
#         }
#
#
#
#         .note-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .note-content {
#
#             line-height:1.5;
#
#         }
#
#         .warning-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #999999;
#
#             background:#fafafa;
#
#         }
#
#
#
#         .warning-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .warning-content {
#
#             line-height:1.5;
#
#         }
#
#         .example-box {
#
#             margin-top:20px;
#
#             padding:15px;
#
#             border-radius:10px;
#
#             border-left:6px solid #888888;
#
#             background:#f8f8f8;
#
#         }
#
#
#
#         .example-title {
#
#             font-weight:bold;
#
#             margin-bottom:8px;
#
#         }
#
#
#
#         .example-content {
#
#             line-height:1.5;
#
#         }
#
#         .image-wrapper {
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#             text-align:center;
#
#         }
#
#         .card-list {
#
#             margin-top: 15px;
#
#             margin-bottom: 15px;
#
#             line-height: 1.6;
#
#         }
#
#
#
#         .card-image {
#
#             max-width:100%;
#
#             border-radius:10px;
#
#         }
#
#         .card-row {
#
#             display:flex;
#
#             align-items:center;
#
#             gap:25px;
#
#             margin-top:20px;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .row-item {
#
#             min-width:0;
#
#         }
#
#         .card-column {
#
#             display:flex;
#
#             flex-direction:column;
#
#             gap:15px;
#
#         }
#
#
#         .lesson-wrapper {
#
#             width:900px;
#             margin:auto;
#
#             font-family:
#             Arial, sans-serif;
#
#         }
#
#
#
#         .lesson-title {
#
#             font-size:28px;
#             font-weight:bold;
#
#             text-align:center;
#
#             margin-bottom:20px;
#
#         }
#
#
#
#         .lesson-main {
#
#             display:flex;
#
#             align-items:center;
#
#             justify-content:center;
#
#             gap:25px;
#
#         }
#
#
#
#         .lesson-card {
#
#             width:650px;
#
#             min-height:300px;
#
#             border:
#             1px solid #cccccc;
#
#             border-radius:14px;
#
#             padding:30px;
#
#             box-shadow:
#             0px 3px 8px rgba(0,0,0,0.15);
#
#         }
#
#
#
#         .nav-button {
#
#             width:45px;
#
#             height:70px;
#
#             border-radius:10px;
#
#             border:
#             1px solid #aaaaaa;
#
#             background:white;
#
#             font-size:25px;
#
#             cursor:pointer;
#
#         }
#
#
#
#         .nav-button:hover {
#
#             background:#eeeeee;
#
#         }
#
#
#
#         .lesson-progress {
#
#             text-align:center;
#
#             margin-top:20px;
#
#             color:#666666;
#
#             font-size:15px;
#
#         }
#
#         .code-wrapper {
#
#             position: relative;
#
#             margin-top: 20px;
#
#             margin-bottom: 20px;
#
#         }
#
#
#         .copy-button {
#
#             position: absolute;
#
#             top: 8px;
#
#             right: 8px;
#
#             border: none;
#
#             background: transparent;
#
#             cursor: pointer;
#
#             font-size: 18px;
#
#             opacity: 0.6;
#
#         }
#
#         .copy-button:hover {
#
#             opacity: 1;
#
#         }
#
#
#
#         .code-block {
#
#             background: #f2f2f2;
#
#             border: 1px solid #dddddd;
#
#             border-radius: 8px;
#
#             padding: 18px;
#
#             overflow-x: auto;
#
#             font-family: "Courier New", monospace;
#
#             font-size: 14px;
#
#         }
#
#
#         </style>
#
#
#
#         <script type="text/javascript">
#
#         function copyCode(id){
#
#             navigator.clipboard.writeText(
#                 document
#                 .getElementById(id)
#                 .innerText
#                 .trim()
#             );
#
#         }
#
#         let cards_lesson_c1d911d17d1b40f697534ed28776c5f5 = ["\n        <h2 class=\"card-heading\">\n            How to Extract a Column as an Array\n        </h2>\n        \n        <div class=\"card-text\">\n            The main way we extract any sort of information from a table is by extracting the relevant column as an array. It is in this array format (which you learned in lab 2) that you can use all sorts of statistical functions to evaluate the data.\n        </div>\n        \n        <div class=\"card-text\">\n            A column can be extracted by one of two ways below.\n        </div>\n        \n\n        <div class=\"card-row\">\n\n            \n\n            <div class=\"row-item\"\n            style=\"flex:1;\">\n\n                \n\n        <div class=\"code-wrapper\">\n\n            <button\n                class=\"copy-button\"\n                onclick=\"copyCode('code_d052340a544841fdae2e1565fccc2d45')\">\n        \n                \ud83d\udccb\n        \n            </button>\n        \n            <pre id=\"code_d052340a544841fdae2e1565fccc2d45\" class=\"code-block\">table.column(&#x27;header&#x27;)</pre>\n        \n        </div>\n\n        \n\n            </div>\n\n            \n\n            <div class=\"row-item\"\n            style=\"flex:1;\">\n\n                \n\n        <div class=\"code-wrapper\">\n\n            <button\n                class=\"copy-button\"\n                onclick=\"copyCode('code_ebc87a869f364e119f51ce0bd3450aa6')\">\n        \n                \ud83d\udccb\n        \n            </button>\n        \n            <pre id=\"code_ebc87a869f364e119f51ce0bd3450aa6\" class=\"code-block\">table[&#x27;header&#x27;]</pre>\n        \n        </div>\n\n        \n\n            </div

# %% [markdown]
# This section below I am using to make examples to be put in the cards.

# %%
from datascience import *

# %%
apple_data = ["Honeycrisp	Red	150	0.90",
    "Gala	Red	140	0.80",
    "Honeycrisp	Red	165	0.99",
    "Granny Smith	Green	175	1.05",
    "Gala	Yellow	145	0.82",
    "Fuji	Red	170	0.95",
    "Honeycrisp	Green	155	0.92",
    "Fuji	Red	180	1.00",
    "Granny Smith	Green	168	1.02",
    "Gala	Red	150	0.85"]

# %%
apple_data = [x.split('	') for x in apple_data]
apple_data
# Out:
# [['Honeycrisp', 'Red', '150', '0.90'],
#  ['Gala', 'Red', '140', '0.80'],
#  ['Honeycrisp', 'Red', '165', '0.99'],
#  ['Granny Smith', 'Green', '175', '1.05'],
#  ['Gala', 'Yellow', '145', '0.82'],
#  ['Fuji', 'Red', '170', '0.95'],
#  ['Honeycrisp', 'Green', '155', '0.92'],
#  ['Fuji', 'Red', '180', '1.00'],
#  ['Granny Smith', 'Green', '168', '1.02'],
#  ['Gala', 'Red', '150', '0.85']]

# %%
from datascience import *
apple_table = Table().with_columns('Type', [], 'Color', [], 'Weight (g)', [], 'Price ($)', [])
apple_table
# Out:
# Type | Color | Weight (g) | Price ($)

# %%
apple_table = apple_table.with_rows(apple_data)

# %%
apple_table.column(2)
# Out:
# array(['150', '140', '165', '175', '145', '170', '155', '180', '168', '150'],
#       dtype='<U3')

# %%
apple_table.sort('Weight (g)', descending=True)
# Out:
# Type         | Color  | Weight (g) | Price ($)
# Fuji         | Red    | 180        | 1.00
# Granny Smith | Green  | 175        | 1.05
# Fuji         | Red    | 170        | 0.95
# Granny Smith | Green  | 168        | 1.02
# Honeycrisp   | Red    | 165        | 0.99
# Honeycrisp   | Green  | 155        | 0.92
# Honeycrisp   | Red    | 150        | 0.90
# Gala         | Red    | 150        | 0.85
# Gala         | Yellow | 145        | 0.82
# Gala         | Red    | 140        | 0.80
