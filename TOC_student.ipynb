# %% [markdown]
# <img src="Temple_flag_morn.png" alt="Temple University" style="width:180px;float:right;margin:8px;"/>
#
# # 🔬 STEM Data Science
# ### Temple University · Summer Program · Middle School
#
# ---
#
# ## 📚 Activities & Labs
#
# *Click any button to open the notebook on the hub.*
#
# <div style="margin:12px 0;">
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2Flab00_middle_school.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">🔬 Lab 00</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">Introduction to Data Science</span>
#   </div>
# </a>
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2Flab01_middle_school.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">🔬 Lab 01</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">Introduction to Python as a Tool</span>
#   </div>
# </a>
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2FActivity1_Planetary_Data_Lab.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">🪐 Activity 1</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">Planetary Data Lab</span>
#   </div>
# </a>
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2FActivity2_Planet_Builder_Simulator.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">🚀 Activity 2</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">Planet Builder Simulator</span>
#   </div>
# </a>
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2Flab02%2Flab2_middle_school.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">🧮 Lab 02</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">Data types — numbers, strings, arrays</span>
#   </div>
# </a>
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2Flab03%2Flab3_middle_school.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">🗃️ Lab 03</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">Tables — organising data</span>
#   </div>
# </a>
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2FLab04-Functions-A.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">⚙️ Lab 04</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">Functions</span>
#   </div>
# </a>
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2FPlant_Explorer.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">🌿 Plant Similarity: Photo Investigation</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">Plant Identification</span>
#   </div>
# </a>
# <a href="https://temple.2i2c.cloud/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Flaserchemist%2FSTEMDS&urlpath=lab%2Ftree%2FSTEMDS%2FCode_Library.ipynb&branch=main" target="_blank" style="text-decoration:none;">
#   <div style="background:#9B2335;color:white;border-radius:10px;padding:16px 24px;margin:8px 4px;display:inline-block;min-width:340px;max-width:420px;vertical-align:top;box-shadow:2px 2px 6px rgba(0,0,0,0.18);">
#     <span style="font-size:1.25em;font-weight:700;">📖 Your Code Library</span><br>
#     <span style="font-size:1.0em;opacity:0.92;">For all your coding needs :)</span>
#   </div>
# </a>
# </div>
#
# ## 🔗 Resources
#
# - [Inferential Thinking — Online Textbook](https://inferentialthinking.com/chapters/intro.html)
# - [Datascience Table Reference](http://data8.org/datascience/index.html)
# - [Data Science Primer](https://laserchemist.github.io/dprimer/intro.html)
# - [EDS Course Website](https://sites.temple.edu/data/)
